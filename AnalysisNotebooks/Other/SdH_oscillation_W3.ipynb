# %%
import numpy as np
import time
import matplotlib.pyplot as plt
import qcodes as qc
import qtplot.qtplot
import matplotlib.colors as colors
# %gui qt
import qcodes.instrument_drivers.nplab_drivers as npd
from matplotlib.colors import SymLogNorm

# %%
from scipy.interpolate import RectBivariateSpline
from scipy.ndimage import gaussian_filter

# %%
# %matplotlib notebook

# %%
import matplotlib.colors as colors

# %%
data_osm1 = qc.load_data('data/2020-04-04/#006_W3_865_48-24_830_47-48_baseT_fieldsweep_-0.5Vbg_15nA_16-25-36')
data_os0 = qc.load_data('data/2020-04-04/#005_W3_865_48-24_830_47-48_baseT_fieldsweep_-0.6Vbg_15nA_13-42-31')
data_os1 = qc.load_data('data/2020-04-04/#004_W3_865_48-24_830_47-48_baseT_fieldsweep_-0.7Vbg_15nA_06-46-20')
data_os2 = qc.load_data('data/2020-04-04/#003_W3_865_48-24_830_47-48_baseT_fieldsweep_-0.8Vbg_15nA_04-45-00')
data_os3 = qc.load_data('data/2020-04-03/#006_W3_865_48-24_830_47-48_baseT_fieldsweep_-0.9Vbg_15nA_11-18-14')
data_os4 = qc.load_data('data/2020-04-04/#002_W3_865_48-24_830_47-48_baseT_fieldsweep_-1Vbg_15nA_02-43-43')
data_os5 = qc.load_data('data/2020-04-03/#007_W3_865_48-24_830_47-48_baseT_fieldsweep_-1.1Vbg_15nA_13-26-29')
data_os6 = qc.load_data('data/2020-04-03/#011_W3_865_48-24_830_47-48_baseT_fieldsweep_-1.2Vbg_15nA_22-41-04')
data_os7 = qc.load_data('data/2020-04-03/#008_W3_865_48-24_830_47-48_baseT_fieldsweep_-1.3Vbg_15nA_15-42-14')
data_os8 = qc.load_data('data/2020-04-03/#010_W3_865_48-24_830_47-48_baseT_fieldsweep_-1.4Vbg_15nA_20-39-45')
data_os9 = qc.load_data('data/2020-04-03/#009_W3_865_48-24_830_47-48_baseT_fieldsweep_-1.5Vbg_15nA_17-55-23')
data_os10 = qc.load_data('data/2020-04-04/#001_W3_865_48-24_830_47-48_baseT_fieldsweep_-1.6Vbg_15nA_00-42-23')
data_os11 = qc.load_data('data/2020-04-04/#007_W3_865_48-24_830_47-48_baseT_fieldsweep_-1.7Vbg_15nA_18-49-39')
data_os12 = qc.load_data('data/2020-04-04/#008_W3_865_48-24_830_47-48_baseT_fieldsweep_-1.8Vbg_15nA_20-53-28')
data_os13 = qc.load_data('data/2020-04-05/#001_W3_865_48-24_830_47-48_baseT_fieldsweep_-1.9Vbg_15nA_00-33-21')
data_os14 = qc.load_data('data/2020-04-05/#002_W3_865_48-24_830_47-48_baseT_fieldsweep_-2.0Vbg_15nA_02-34-40')
data_os15 = qc.load_data('data/2020-04-05/#005_W3_865_48-24_830_47-48_baseT_fieldsweep_-2.1Vbg_15nA_10-54-50')
data_os16 = qc.load_data('data/2020-04-05/#007_W3_865_48-24_830_47-48_baseT_fieldsweep_-2.2Vbg_15nA_16-22-21')

# %%
#plot Rxx-1/B
#lockin830  contact 48-47 ~1 degree
plt.figure()

Nmin = 250

datam1 = data_osm1
dlastm1 = np.where(np.isnan(datam1.triton_field[:]))[0][0]
dnegm1 = npd.val_to_index([0], datam1.triton_field[:dlastm1])[0] - Nmin
#plt.plot(1/datam1.triton_field[:dnegm1], gaussian_filter(datam1.lockin830_X[:dnegm1]/15e-9,2), label='-0.5Vg')

data0 = data_os0
dlast0 = np.where(np.isnan(data0.triton_field[:]))[0][0]
dneg0 = npd.val_to_index([0], data0.triton_field[:dlast0])[0] + Nmin
#plt.plot(1/data0.triton_field[dneg0:dlast0], gaussian_filter(data0.lockin830_X[dneg0:dlast0]/15e-9,2), label='-0.6Vg')


data1 = data_os1
dlast1 = np.where(np.isnan(data1.triton_field[:]))[0][0]
dneg1 = npd.val_to_index([0], data1.triton_field[:dlast1])[0] - Nmin
#plt.plot(1/data1.triton_field[:dneg1], gaussian_filter(data1.lockin830_X[:dneg1]/15e-9,2), label='-0.7Vg')

data2 = data_os2
dlast2 = np.where(np.isnan(data2.triton_field[:]))[0][0]
dneg2 = npd.val_to_index([0], data2.triton_field[:dlast2])[0] + Nmin
#plt.plot(1/data2.triton_field[dneg2:dlast2], gaussian_filter(data2.lockin830_X[dneg2:dlast2]/15e-9,2), label='-0.8Vg')

data3 = data_os3
dlast3 = np.where(np.isnan(data3.triton_field[:]))[0][0]
dneg3 = npd.val_to_index([0], data3.triton_field[:dlast3])[0] + Nmin
#plt.plot(1/data3.triton_field[dneg3:dlast3], gaussian_filter(data3.lockin830_X[dneg3:dlast3]/15e-9,2), label='-0.9Vg')

data4 = data_os4
dlast4 = np.where(np.isnan(data4.triton_field[:]))[0][0]
dneg4 = npd.val_to_index([0], data4.triton_field[:dlast4])[0] - Nmin
#plt.plot(1/data4.triton_field[:dneg4], gaussian_filter(data4.lockin830_X[:dneg4]/15e-9,2), label='-1.0Vg')

data5 = data_os5
dlast5 = np.where(np.isnan(data5.triton_field[:]))[0][0]
dneg5 = npd.val_to_index([0], data5.triton_field[:dlast5])[0] - Nmin
#plt.plot(1/data5.triton_field[:dneg5], gaussian_filter(data5.lockin830_X[:dneg5]/15e-9,2), label='-1.1Vg')

data6 = data_os6
dlast6 = np.where(np.isnan(data6.triton_field[:]))[0][0]
dneg6 = npd.val_to_index([0], data6.triton_field[:dlast6])[0] - Nmin
#plt.plot(1/data6.triton_field[:dneg6], gaussian_filter(data6.lockin830_X[:dneg6]/15e-9,2), label='-1.2Vg')

data7 = data_os7
dlast7 = np.where(np.isnan(data7.triton_field[:]))[0][0]
dneg7 = npd.val_to_index([0], data7.triton_field[:dlast7])[0] + Nmin
#plt.plot(1/data7.triton_field[dneg7:dlast7], gaussian_filter(data7.lockin830_X[dneg7:dlast7]/15e-9,2), label='-1.3Vg')

data8 = data_os8
dlast8 = np.where(np.isnan(data8.triton_field[:]))[0][0]
dneg8 = npd.val_to_index([0], data8.triton_field[:dlast8])[0] + Nmin
#plt.plot(1/data8.triton_field[dneg8:dlast8], gaussian_filter(data8.lockin830_X[dneg8:dlast8]/15e-9,2), label='-1.4Vg')

data9 = data_os9
dlast9 = np.where(np.isnan(data9.triton_field[:]))[0][0]
dneg9 = npd.val_to_index([0], data9.triton_field[:dlast9])[0] - Nmin
#plt.plot(1/data9.triton_field[:dneg9], gaussian_filter(data9.lockin830_X[:dneg9]/15e-9,2), label='-1.5Vg')

data10 = data_os10
dlast10 = np.where(np.isnan(data10.triton_field[:]))[0][0]
dneg10 = npd.val_to_index([0], data10.triton_field[:dlast10])[0] + Nmin
#plt.plot(1/data10.triton_field[dneg10:dlast10], gaussian_filter(data10.lockin830_X[dneg10:dlast10]/15e-9,2), label='-1.6Vg')

data11 = data_os11
dlast11 = np.where(np.isnan(data11.triton_field[:]))[0][0]
dneg11 = npd.val_to_index([0], data11.triton_field[:dlast11])[0] + Nmin
#plt.plot(1/data11.triton_field[dneg11:dlast11], gaussian_filter(data11.lockin830_X[dneg11:dlast11]/15e-9,2), label='-1.7Vg')

data12 = data_os12
dlast12 = np.where(np.isnan(data12.triton_field[:]))[0][0]
dneg12 = npd.val_to_index([0], data12.triton_field[:dlast12])[0] - Nmin
#plt.plot(1/data12.triton_field[:dneg12], gaussian_filter(data12.lockin830_X[:dneg12]/15e-9,2), label='-1.8Vg')

data13 = data_os13
dlast13 = np.where(np.isnan(data13.triton_field[:]))[0][0]
dneg13 = npd.val_to_index([0], data13.triton_field[:dlast13])[0] + Nmin
plt.plot(1/data13.triton_field[dneg13:dlast13], gaussian_filter(data13.lockin830_X[dneg13:dlast13]/15e-9,2), label='-1.9Vg')

data14 = data_os14
dlast14 = np.where(np.isnan(data14.triton_field[:]))[0][0]
dneg14 = npd.val_to_index([0], data14.triton_field[:dlast14])[0] - Nmin
plt.plot(1/data14.triton_field[:dneg14], gaussian_filter(data14.lockin830_X[:dneg14]/15e-9,2), label='-2.0Vg')

data15 = data_os15
dlast15 = np.where(np.isnan(data15.triton_field[:]))[0][0]
dneg15 = npd.val_to_index([0], data15.triton_field[:dlast15])[0] + Nmin
plt.plot(1/data15.triton_field[dneg15:dlast15], gaussian_filter(data15.lockin830_X[dneg15:dlast15]/15e-9,2), label='-2.1Vg')

data16 = data_os16
dlast16 = np.where(np.isnan(data16.triton_field[:]))[0][0]
dneg16 = npd.val_to_index([0], data16.triton_field[:dlast16])[0] + Nmin
plt.plot(1/data16.triton_field[dneg16:dlast16], gaussian_filter(data16.lockin830_X[dneg16:dlast16]/15e-9,2), label='-2.2Vg')


plt.legend()
# Out:
# <img src="data:image/png;base64,..." width="640">
# 0.00 is not a value in the array
# Plotted 0.00 instead
# 0.00 is not a value in the array
# Plotted 0.00 instead
# 0.00 is not a value in the array
# Plotted 0.00 instead
# 0.00 is not a value in the array
# Plotted 0.00 instead
# 0.00 is not a value in the array
# Plotted 0.00 instead
# 0.00 is not a value in the array
# Plotted 0.00 instead
# 0.00 is not a value in the array
# Plotted -0.00 instead
# 0.00 is not a value in the array
# Plotted -0.00 instead
# 0.00 is not a value in the array
# Plotted -0.00 instead
# 0.00 is not a value in the array
# Plotted 0.00 instead
# 0.00 is not a value in the array
# Plotted -0.00 instead
# 0.00 is not a value in the array
# Plotted 0.00 instead
# 0.00 is not a value in the array
# Plotted -0.00 instead
# 0.00 is not a value in the array
# Plotted 0.00 instead
# 0.00 is not a value in the array
# Plotted -0.00 instead

# %%
# interpolation data to get uniform 1/B, plot
n=1000 

inver_Bptsm1 = np.linspace(1/6, 2.2, n)
Rintm1 = np.interp(inver_Bptsm1, 1/datam1.triton_field[:dnegm1], datam1.lockin830_X[:dnegm1]/15e-9)

inver_Bpts0 = np.linspace(2.2, 1/6, n)
Rint0 = np.flip(np.interp(np.flip(inver_Bpts0), np.flip(1/data0.triton_field[dneg0:dlast0]), np.flip(data0.lockin830_X[dneg0:dlast0]/15e-9)))

inver_Bpts1 = np.linspace(1/6, 2.2, n)
Rint1 = np.interp(inver_Bpts1, 1/data1.triton_field[:dneg1], data1.lockin830_X[:dneg1]/15e-9)

inver_Bpts2 = np.linspace(2.2, 1/6, n)
Rint2 = np.flip(np.interp(np.flip(inver_Bpts2), np.flip(1/data2.triton_field[dneg2:dlast2]), np.flip(data2.lockin830_X[dneg2:dlast2]/15e-9)))

inver_Bpts3 = np.linspace(2.2, 1/6, n)
Rint3 = np.flip(np.interp(np.flip(inver_Bpts3), np.flip(1/data3.triton_field[dneg3:dlast3]), np.flip(data3.lockin830_X[dneg3:dlast3]/15e-9)))

inver_Bpts4 = np.linspace(1/6, 2.2, n)
Rint4 = np.interp(inver_Bpts4, 1/data4.triton_field[:dneg4], data4.lockin830_X[:dneg4]/15e-9)

inver_Bpts5 = np.linspace(1/6, 2.2, n)
Rint5 = np.interp(inver_Bpts5, 1/data5.triton_field[:dneg5], data5.lockin830_X[:dneg5]/15e-9)

inver_Bpts6 = np.linspace(1/6, 2.2, n)
Rint6 = np.interp(inver_Bpts6, 1/data6.triton_field[:dneg6], data6.lockin830_X[:dneg6]/15e-9)

inver_Bpts7 = np.linspace(2.2, 1/6, n)
Rint7 = np.flip(np.interp(np.flip(inver_Bpts7), np.flip(1/data7.triton_field[dneg7:dlast7]), np.flip(data7.lockin830_X[dneg7:dlast7]/15e-9)))

inver_Bpts8 = np.linspace(2.2, 1/6, n)
Rint8 = np.flip(np.interp(np.flip(inver_Bpts8), np.flip(1/data8.triton_field[dneg8:dlast8]), np.flip(data8.lockin830_X[dneg8:dlast8]/15e-9)))

inver_Bpts9 = np.linspace(1/6, 2.2, n)
Rint9 = np.interp(inver_Bpts9, 1/data9.triton_field[:dneg9], data9.lockin830_X[:dneg9]/15e-9)

inver_Bpts10 = np.linspace(2.2, 1/6, n)
Rint10 = np.flip(np.interp(np.flip(inver_Bpts10), np.flip(1/data10.triton_field[dneg10:dlast10]), np.flip(data10.lockin830_X[dneg10:dlast10]/15e-9)))

inver_Bpts11 = np.linspace(2.2, 1/6, n)
Rint11 = np.flip(np.interp(np.flip(inver_Bpts11), np.flip(1/data11.triton_field[dneg11:dlast11]), np.flip(data11.lockin830_X[dneg11:dlast11]/15e-9)))

inver_Bpts12 = np.linspace(1/6, 2.2, n)
Rint12 = np.interp(inver_Bpts12, 1/data12.triton_field[:dneg12], data12.lockin830_X[:dneg12]/15e-9)

inver_Bpts13 = np.linspace(2.2, 1/6, n)
Rint13 = np.flip(np.interp(np.flip(inver_Bpts13), np.flip(1/data13.triton_field[dneg13:dlast13]), np.flip(data13.lockin830_X[dneg13:dlast13]/15e-9)))

inver_Bpts14 = np.linspace(1/6, 2.2, n)
Rint14 = np.interp(inver_Bpts14, 1/data14.triton_field[:dneg14], data14.lockin830_X[:dneg14]/15e-9)

inver_Bpts15 = np.linspace(2.2, 1/6, n)
Rint15 = np.flip(np.interp(np.flip(inver_Bpts15), np.flip(1/data15.triton_field[dneg15:dlast15]), np.flip(data15.lockin830_X[dneg15:dlast15]/15e-9)))

inver_Bpts16 = np.linspace(2.2, 1/6, n)
Rint16 = np.flip(np.interp(np.flip(inver_Bpts16), np.flip(1/data16.triton_field[dneg16:dlast16]), np.flip(data16.lockin830_X[dneg16:dlast16]/15e-9)))




plt.figure(figsize=(8, 9))
#plt.plot(inver_Bptsm1, Rintm1-6500, label='-0.5Vg')
plt.plot(inver_Bpts0, Rint0-4500, label='-0.6Vg')
plt.plot(inver_Bpts1, Rint1-3000, label='-0.7Vg')
plt.plot(inver_Bpts2, Rint2-1500, label='-0.8Vg')
plt.plot(inver_Bpts3, Rint3, label='-0.9Vg')
plt.plot(inver_Bpts4, Rint4+1500, label='-1.0Vg')
plt.plot(inver_Bpts5, Rint5+3000, label='-1.1Vg')
plt.plot(inver_Bpts6, Rint6+4500, label='-1.2Vg')
plt.plot(inver_Bpts7, Rint7+6000, label='-1.3Vg')
plt.plot(inver_Bpts8, Rint8+7500, label='-1.4Vg')
plt.plot(inver_Bpts9, Rint9+9000, label='-1.5Vg')
plt.plot(inver_Bpts10, Rint10+10500, label='-1.6Vg')
plt.plot(inver_Bpts11, Rint11+12000, label='-1.7Vg')
plt.plot(inver_Bpts12, Rint12+13500, label='-1.8Vg')
plt.plot(inver_Bpts13, Rint13+15000, label='-1.9Vg')
plt.plot(inver_Bpts14, Rint14+16500, label='-2.0Vg')
plt.plot(inver_Bpts15, Rint15+17000, label='-2.1Vg')
plt.plot(inver_Bpts16, Rint16+18000, label='-2.2Vg')
plt.axis((0.1, 1.6, -5000, 24500))
plt.xlabel('1/B')
plt.legend(loc='upper right')
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
from scipy.fftpack import fft

# %%
#FFT and plot

signalFFTm1 = fft(Rintm1)
signalPSDm1 = np.abs(signalFFTm1) ** 2
fftFreqm1 = np.fft.fftfreq(len(signalPSDm1), (inver_Bptsm1[1]-inver_Bptsm1[0]))

signalFFT0 = fft(Rint0)
signalPSD0 = np.abs(signalFFT0) ** 2
fftFreq0 = np.fft.fftfreq(len(signalPSD0), (inver_Bpts0[1]-inver_Bpts0[0]))

signalFFT1 = fft(Rint1)
signalPSD1 = np.abs(signalFFT1) ** 2
fftFreq1 = np.fft.fftfreq(len(signalPSD1), (inver_Bpts1[1]-inver_Bpts1[0]))


signalFFT2 = fft(Rint2)
signalPSD2 = np.abs(signalFFT2) ** 2
fftFreq2 = np.fft.fftfreq(len(signalPSD2), abs(inver_Bpts2[1]-inver_Bpts2[0]))

signalFFT3 = fft(Rint3)
signalPSD3 = np.abs(signalFFT3) ** 2
fftFreq3 = np.fft.fftfreq(len(signalPSD3), abs(inver_Bpts3[1]-inver_Bpts3[0]))

signalFFT4 = fft(Rint4)
signalPSD4 = np.abs(signalFFT4) ** 2
fftFreq4 = np.fft.fftfreq(len(signalPSD4), abs(inver_Bpts4[1]-inver_Bpts4[0]))

signalFFT5 = fft(Rint5)
signalPSD5 = np.abs(signalFFT5) ** 2
fftFreq5 = np.fft.fftfreq(len(signalPSD5), abs(inver_Bpts5[1]-inver_Bpts5[0]))

signalFFT6 = fft(Rint6)
signalPSD6 = np.abs(signalFFT6) ** 2
fftFreq6 = np.fft.fftfreq(len(signalPSD6), abs(inver_Bpts6[1]-inver_Bpts6[0]))

signalFFT7 = fft(Rint7)
signalPSD7 = np.abs(signalFFT7) ** 2
fftFreq7 = np.fft.fftfreq(len(signalPSD7), abs(inver_Bpts7[1]-inver_Bpts7[0]))

signalFFT8 = fft(Rint8)
signalPSD8 = np.abs(signalFFT8) ** 2
fftFreq8 = np.fft.fftfreq(len(signalPSD8), abs(inver_Bpts8[1]-inver_Bpts8[0]))

signalFFT9 = fft(Rint9)
signalPSD9 = np.abs(signalFFT9) ** 2
fftFreq9 = np.fft.fftfreq(len(signalPSD9), abs(inver_Bpts9[1]-inver_Bpts9[0]))

signalFFT10 = fft(Rint10)
signalPSD10 = np.abs(signalFFT10) ** 2
fftFreq10 = np.fft.fftfreq(len(signalPSD10), abs(inver_Bpts10[1]-inver_Bpts10[0]))

signalFFT11 = fft(Rint11)
signalPSD11 = np.abs(signalFFT11) ** 2
fftFreq11 = np.fft.fftfreq(len(signalPSD11), abs(inver_Bpts11[1]-inver_Bpts11[0]))

signalFFT12 = fft(Rint12)
signalPSD12 = np.abs(signalFFT12) ** 2
fftFreq12 = np.fft.fftfreq(len(signalPSD12), abs(inver_Bpts12[1]-inver_Bpts12[0]))

signalFFT13 = fft(Rint13)
signalPSD13 = np.abs(signalFFT13) ** 2
fftFreq13 = np.fft.fftfreq(len(signalPSD13), abs(inver_Bpts13[1]-inver_Bpts13[0]))

signalFFT14 = fft(Rint14)
signalPSD14 = np.abs(signalFFT14) ** 2
fftFreq14 = np.fft.fftfreq(len(signalPSD14), abs(inver_Bpts14[1]-inver_Bpts14[0]))

signalFFT15 = fft(Rint15)
signalPSD15 = np.abs(signalFFT15) ** 2
fftFreq15 = np.fft.fftfreq(len(signalPSD15), abs(inver_Bpts15[1]-inver_Bpts15[0]))

signalFFT16 = fft(Rint16)
signalPSD16 = np.abs(signalFFT16) ** 2
fftFreq16 = np.fft.fftfreq(len(signalPSD16), abs(inver_Bpts16[1]-inver_Bpts16[0]))

im1 = fftFreqm1>0
i0 = fftFreq0>0
i1 = fftFreq1>0
i2 = fftFreq2>0
i3 = fftFreq3>0
i4 = fftFreq4>0
i5 = fftFreq5>0
i6 = fftFreq6>0
i7 = fftFreq7>0
i8 = fftFreq8>0
i9 = fftFreq9>0
i10 = fftFreq10>0
i11 = fftFreq11>0
i12 = fftFreq12>0
i13 = fftFreq13>0
i14 = fftFreq14>0
i15 = fftFreq15>0
i16 = fftFreq16>0
                       

plt.figure(figsize=(6, 9))
#plt.plot(fftFreqm1[im1], signalPSDm1[im1]-34e9,  label='-0.5Vg');
plt.plot(fftFreq0[i0], signalPSD0[i0]-19e9,  label='-0.6Vg');
plt.plot(fftFreq1[i1], signalPSD1[i1]-14e9,  label='-0.7Vg');
plt.plot(fftFreq2[i2], signalPSD2[i2]-6e9,  label='-0.8Vg');
plt.plot(fftFreq3[i3], signalPSD3[i3]+2e9, label='-0.9Vg');
plt.plot(fftFreq4[i4], signalPSD4[i4]+9e9, label='-1.0Vg');
plt.plot(fftFreq5[i5], signalPSD5[i5]+13e9, label='-1.1Vg');
plt.plot(fftFreq6[i6], signalPSD6[i6]+16e9, label='-1.2Vg');
plt.plot(fftFreq7[i7], signalPSD7[i7]+19e9, label='-1.3Vg');
plt.plot(fftFreq8[i8], signalPSD8[i8]+22e9, label='-1.4Vg');
plt.plot(fftFreq9[i9], signalPSD9[i9]+25e9, label='-1.5Vg');
plt.plot(fftFreq10[i10], signalPSD10[i10]+29e9, label='-1.6Vg');
plt.plot(fftFreq11[i11], signalPSD11[i11]+35e9, label='-1.7Vg');
plt.plot(fftFreq12[i12], signalPSD12[i12]+43e9, label='-1.8Vg');
plt.plot(fftFreq13[i13], signalPSD13[i13]+50e9, label='-1.9Vg');
plt.plot(fftFreq14[i14], signalPSD14[i14]+56e9, label='-2.0Vg');
plt.plot(fftFreq15[i15], signalPSD15[i15]+61e9, label='-2.1Vg');
plt.plot(fftFreq16[i16], signalPSD16[i16]+64e9, label='-2.2Vg');
plt.axis((0, 30, -20e9, 8.5e10))
plt.xlabel('frequency (T)')
plt.legend(loc='upper right')
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
Freq_amplitude = np.zeros((len(fftFreq0),17))

# %%
for i in range(len(fftFreq0)):
    Freq_amplitude[i,0] = signalFFT0[i]/1e2
    Freq_amplitude[i,1] = signalFFT1[i]/1e2
    Freq_amplitude[i,2] = signalFFT2[i]/1e2
    Freq_amplitude[i,3] = signalFFT3[i]/1e2
    Freq_amplitude[i,4] = signalFFT4[i]/1e2
    Freq_amplitude[i,5] = signalFFT5[i]/1e2
    Freq_amplitude[i,6] = signalFFT6[i]/1e2
    Freq_amplitude[i,7] = signalFFT7[i]/1e2
    Freq_amplitude[i,8] = signalFFT8[i]/1e2
    Freq_amplitude[i,9] = signalFFT9[i]/1e2
    Freq_amplitude[i,10] = signalFFT10[i]/1e2
    Freq_amplitude[i,11] = signalFFT11[i]/1e2
    Freq_amplitude[i,12] = signalFFT12[i]/1e2
    Freq_amplitude[i,13] = signalFFT13[i]/1e2
    Freq_amplitude[i,14] = signalFFT14[i]/1e2
    Freq_amplitude[i,15] = signalFFT15[i]/1e2
    Freq_amplitude[i,16] = signalFFT16[i]/1e2
# Out:
# C:\Users\NPLAB\Anaconda3\envs\qcodes\lib\site-packages\ipykernel_launcher.py:2: ComplexWarning: Casting complex values to real discards the imaginary part
#
# C:\Users\NPLAB\Anaconda3\envs\qcodes\lib\site-packages\ipykernel_launcher.py:3: ComplexWarning: Casting complex values to real discards the imaginary part
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\NPLAB\Anaconda3\envs\qcodes\lib\site-packages\ipykernel_launcher.py:4: ComplexWarning: Casting complex values to real discards the imaginary part
#   after removing the cwd from sys.path.
# C:\Users\NPLAB\Anaconda3\envs\qcodes\lib\site-packages\ipykernel_launcher.py:5: ComplexWarning: Casting complex values to real discards the imaginary part
#   """
# C:\Users\NPLAB\Anaconda3\envs\qcodes\lib\site-packages\ipykernel_launcher.py:6: ComplexWarning: Casting complex values to real discards the imaginary part
#
# ...

# %%
Vg = np.zeros(17)
for i in range(17):
    Vg[i] = -0.6-i*0.1

# %%
plt.figure(figsize=(4,8))
plt.pcolormesh(Vg,fftFreq0[920:1000],Freq_amplitude[920:1000,:],cmap='inferno',norm = colors.SymLogNorm(500))
# Out:
# <img src="data:image/png;base64,..." width="400">

# %%
plt.figure(figsize=(4,6))
plt.pcolormesh(Vg,fftFreq0[950:1000],Freq_amplitude[950:1000,:],cmap='inferno',norm = colors.SymLogNorm(500,vmin=20, vmax=1000))
# Out:
# <img src="data:image/png;base64,..." width="400">

# %%
#plot Rxx-1/B
#lockin865  contact 48-24 ~1.1 degree
plt.figure()

Nmin = 250

datam1 = data_osm1
dlastm1 = np.where(np.isnan(datam1.triton_field[:]))[0][0]
dnegm1 = npd.val_to_index([0], datam1.triton_field[:dlastm1])[0] - Nmin
#plt.plot(1/datam1.triton_field[:dnegm1], gaussian_filter(datam1.lockin865_X[:dnegm1]/15e-9,2), label='-0.5Vg')

data0 = data_os0
dlast0 = np.where(np.isnan(data0.triton_field[:]))[0][0]
dneg0 = npd.val_to_index([0], data0.triton_field[:dlast0])[0] + Nmin
#plt.plot(1/data0.triton_field[dneg0:dlast0], gaussian_filter(data0.lockin865_X[dneg0:dlast0]/15e-9,2), label='-0.6Vg')


data1 = data_os1
dlast1 = np.where(np.isnan(data1.triton_field[:]))[0][0]
dneg1 = npd.val_to_index([0], data1.triton_field[:dlast1])[0] - Nmin
#plt.plot(1/data1.triton_field[:dneg1], gaussian_filter(data1.lockin865_X[:dneg1]/15e-9,2), label='-0.7Vg')

data2 = data_os2
dlast2 = np.where(np.isnan(data2.triton_field[:]))[0][0]
dneg2 = npd.val_to_index([0], data2.triton_field[:dlast2])[0] + Nmin
#plt.plot(1/data2.triton_field[dneg2:dlast2], gaussian_filter(data2.lockin865_X[dneg2:dlast2]/15e-9,2), label='-0.8Vg')

data3 = data_os3
dlast3 = np.where(np.isnan(data3.triton_field[:]))[0][0]
dneg3 = npd.val_to_index([0], data3.triton_field[:dlast3])[0] + Nmin
#plt.plot(1/data3.triton_field[dneg3:dlast3], gaussian_filter(data3.lockin865_X[dneg3:dlast3]/15e-9,2), label='-0.9Vg')

data4 = data_os4
dlast4 = np.where(np.isnan(data4.triton_field[:]))[0][0]
dneg4 = npd.val_to_index([0], data4.triton_field[:dlast4])[0] - Nmin
#plt.plot(1/data4.triton_field[:dneg4], gaussian_filter(data4.lockin865_X[:dneg4]/15e-9,2), label='-1.0Vg')

data5 = data_os5
dlast5 = np.where(np.isnan(data5.triton_field[:]))[0][0]
dneg5 = npd.val_to_index([0], data5.triton_field[:dlast5])[0] - Nmin
#plt.plot(1/data5.triton_field[:dneg5], gaussian_filter(data5.lockin865_X[:dneg5]/15e-9,2), label='-1.1Vg')

data6 = data_os6
dlast6 = np.where(np.isnan(data6.triton_field[:]))[0][0]
dneg6 = npd.val_to_index([0], data6.triton_field[:dlast6])[0] - Nmin
#plt.plot(1/data6.triton_field[:dneg6], gaussian_filter(data6.lockin865_X[:dneg6]/15e-9,2), label='-1.2Vg')

data7 = data_os7
dlast7 = np.where(np.isnan(data7.triton_field[:]))[0][0]
dneg7 = npd.val_to_index([0], data7.triton_field[:dlast7])[0] + Nmin
#plt.plot(1/data7.triton_field[dneg7:dlast7], gaussian_filter(data7.lockin865_X[dneg7:dlast7]/15e-9,2), label='-1.3Vg')

data8 = data_os8
dlast8 = np.where(np.isnan(data8.triton_field[:]))[0][0]
dneg8 = npd.val_to_index([0], data8.triton_field[:dlast8])[0] + Nmin
plt.plot(1/data8.triton_field[dneg8:dlast8], gaussian_filter(data8.lockin865_X[dneg8:dlast8]/15e-9,2), label='-1.4Vg')

data9 = data_os9
dlast9 = np.where(np.isnan(data9.triton_field[:]))[0][0]
dneg9 = npd.val_to_index([0], data9.triton_field[:dlast9])[0] - Nmin
plt.plot(1/data9.triton_field[:dneg9], gaussian_filter(data9.lockin865_X[:dneg9]/15e-9,2), label='-1.5Vg')

data10 = data_os10
dlast10 = np.where(np.isnan(data10.triton_field[:]))[0][0]
dneg10 = npd.val_to_index([0], data10.triton_field[:dlast10])[0] + Nmin
plt.plot(1/data10.triton_field[dneg10:dlast10], gaussian_filter(data10.lockin865_X[dneg10:dlast10]/15e-9,2), label='-1.6Vg')

data11 = data_os11
dlast11 = np.where(np.isnan(data11.triton_field[:]))[0][0]
dneg11 = npd.val_to_index([0], data11.triton_field[:dlast11])[0] + Nmin
#plt.plot(1/data11.triton_field[dneg11:dlast11], gaussian_filter(data11.lockin865_X[dneg11:dlast11]/15e-9,2), label='-1.7Vg')

data12 = data_os12
dlast12 = np.where(np.isnan(data12.triton_field[:]))[0][0]
dneg12 = npd.val_to_index([0], data12.triton_field[:dlast12])[0] - Nmin
#plt.plot(1/data12.triton_field[:dneg12], gaussian_filter(data12.lockin865_X[:dneg12]/15e-9,2), label='-1.8Vg')

data13 = data_os13
dlast13 = np.where(np.isnan(data13.triton_field[:]))[0][0]
dneg13 = npd.val_to_index([0], data13.triton_field[:dlast13])[0] + Nmin
#plt.plot(1/data13.triton_field[dneg13:dlast13], gaussian_filter(data13.lockin865_X[dneg13:dlast13]/15e-9,2), label='-1.9Vg')

data14 = data_os14
dlast14 = np.where(np.isnan(data14.triton_field[:]))[0][0]
dneg14 = npd.val_to_index([0], data14.triton_field[:dlast14])[0] - Nmin
#plt.plot(1/data14.triton_field[:dneg14], gaussian_filter(data14.lockin865_X[:dneg14]/15e-9,2), label='-2.0Vg')

data15 = data_os15
dlast15 = np.where(np.isnan(data15.triton_field[:]))[0][0]
dneg15 = npd.val_to_index([0], data15.triton_field[:dlast15])[0] + Nmin
#plt.plot(1/data15.triton_field[dneg15:dlast15], gaussian_filter(data15.lockin865_X[dneg15:dlast15]/15e-9,2), label='-2.1Vg')

data16 = data_os16
dlast16 = np.where(np.isnan(data16.triton_field[:]))[0][0]
dneg16 = npd.val_to_index([0], data16.triton_field[:dlast16])[0] + Nmin
#plt.plot(1/data16.triton_field[dneg16:dlast16], gaussian_filter(data16.lockin865_X[dneg16:dlast16]/15e-9,2), label='-2.2Vg')


plt.legend()
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">
# 0.00 is not a value in the array
# Plotted 0.00 instead
# 0.00 is not a value in the array
# Plotted 0.00 instead
# 0.00 is not a value in the array
# Plotted 0.00 instead
# 0.00 is not a value in the array
# Plotted 0.00 instead
# 0.00 is not a value in the array
# Plotted 0.00 instead
# 0.00 is not a value in the array
# Plotted 0.00 instead
# 0.00 is not a value in the array
# Plotted -0.00 instead
# 0.00 is not a value in the array
# Plotted -0.00 instead
# 0.00 is not a value in the array
# Plotted -0.00 instead
# 0.00 is not a value in the array
# Plotted 0.00 instead
# 0.00 is not a value in the array
# Plotted -0.00 instead
# 0.00 is not a value in the array
# Plotted 0.00 instead
# 0.00 is not a value in the array
# Plotted -0.00 instead
# 0.00 is not a value in the array
# Plotted 0.00 instead
# 0.00 is not a value in the array
# Plotted -0.00 instead

# %%
# interpolation data to get uniform 1/B, plot
n=1000 

inver_Bptsm1 = np.linspace(1/6, 2.2, n)
Rintm1 = np.interp(inver_Bptsm1, 1/datam1.triton_field[:dnegm1], datam1.lockin865_X[:dnegm1]/15e-9)

inver_Bpts0 = np.linspace(2.2, 1/6, n)
Rint0 = np.flip(np.interp(np.flip(inver_Bpts0), np.flip(1/data0.triton_field[dneg0:dlast0]), np.flip(data0.lockin865_X[dneg0:dlast0]/15e-9)))

inver_Bpts1 = np.linspace(1/6, 2.2, n)
Rint1 = np.interp(inver_Bpts1, 1/data1.triton_field[:dneg1], data1.lockin865_X[:dneg1]/15e-9)

inver_Bpts2 = np.linspace(2.2, 1/6, n)
Rint2 = np.flip(np.interp(np.flip(inver_Bpts2), np.flip(1/data2.triton_field[dneg2:dlast2]), np.flip(data2.lockin865_X[dneg2:dlast2]/15e-9)))

inver_Bpts3 = np.linspace(2.2, 1/6, n)
Rint3 = np.flip(np.interp(np.flip(inver_Bpts3), np.flip(1/data3.triton_field[dneg3:dlast3]), np.flip(data3.lockin865_X[dneg3:dlast3]/15e-9)))

inver_Bpts4 = np.linspace(1/6, 2.2, n)
Rint4 = np.interp(inver_Bpts4, 1/data4.triton_field[:dneg4], data4.lockin865_X[:dneg4]/15e-9)

inver_Bpts5 = np.linspace(1/6, 2.2, n)
Rint5 = np.interp(inver_Bpts5, 1/data5.triton_field[:dneg5], data5.lockin865_X[:dneg5]/15e-9)

inver_Bpts6 = np.linspace(1/6, 2.2, n)
Rint6 = np.interp(inver_Bpts6, 1/data6.triton_field[:dneg6], data6.lockin865_X[:dneg6]/15e-9)

inver_Bpts7 = np.linspace(2.2, 1/6, n)
Rint7 = np.flip(np.interp(np.flip(inver_Bpts7), np.flip(1/data7.triton_field[dneg7:dlast7]), np.flip(data7.lockin865_X[dneg7:dlast7]/15e-9)))

inver_Bpts8 = np.linspace(2.2, 1/6, n)
Rint8 = np.flip(np.interp(np.flip(inver_Bpts8), np.flip(1/data8.triton_field[dneg8:dlast8]), np.flip(data8.lockin865_X[dneg8:dlast8]/15e-9)))

inver_Bpts9 = np.linspace(1/6, 2.2, n)
Rint9 = np.interp(inver_Bpts9, 1/data9.triton_field[:dneg9], data9.lockin865_X[:dneg9]/15e-9)

inver_Bpts10 = np.linspace(2.2, 1/6, n)
Rint10 = np.flip(np.interp(np.flip(inver_Bpts10), np.flip(1/data10.triton_field[dneg10:dlast10]), np.flip(data10.lockin865_X[dneg10:dlast10]/15e-9)))

inver_Bpts11 = np.linspace(2.2, 1/6, n)
Rint11 = np.flip(np.interp(np.flip(inver_Bpts11), np.flip(1/data11.triton_field[dneg11:dlast11]), np.flip(data11.lockin865_X[dneg11:dlast11]/15e-9)))

inver_Bpts12 = np.linspace(1/6, 2.2, n)
Rint12 = np.interp(inver_Bpts12, 1/data12.triton_field[:dneg12], data12.lockin865_X[:dneg12]/15e-9)

inver_Bpts13 = np.linspace(2.2, 1/6, n)
Rint13 = np.flip(np.interp(np.flip(inver_Bpts13), np.flip(1/data13.triton_field[dneg13:dlast13]), np.flip(data13.lockin865_X[dneg13:dlast13]/15e-9)))

inver_Bpts14 = np.linspace(1/6, 2.2, n)
Rint14 = np.interp(inver_Bpts14, 1/data14.triton_field[:dneg14], data14.lockin865_X[:dneg14]/15e-9)

inver_Bpts15 = np.linspace(2.2, 1/6, n)
Rint15 = np.flip(np.interp(np.flip(inver_Bpts15), np.flip(1/data15.triton_field[dneg15:dlast15]), np.flip(data15.lockin865_X[dneg15:dlast15]/15e-9)))

inver_Bpts16 = np.linspace(2.2, 1/6, n)
Rint16 = np.flip(np.interp(np.flip(inver_Bpts16), np.flip(1/data16.triton_field[dneg16:dlast16]), np.flip(data16.lockin865_X[dneg16:dlast16]/15e-9)))




plt.figure(figsize=(8, 9))
#plt.plot(inver_Bptsm1, Rintm1-6500, label='-0.5Vg')
plt.plot(inver_Bpts0, Rint0-4500, label='-0.6Vg')
plt.plot(inver_Bpts1, Rint1-3000, label='-0.7Vg')
plt.plot(inver_Bpts2, Rint2-1500, label='-0.8Vg')
plt.plot(inver_Bpts3, Rint3, label='-0.9Vg')
plt.plot(inver_Bpts4, Rint4+1500, label='-1.0Vg')
plt.plot(inver_Bpts5, Rint5+3000, label='-1.1Vg')
plt.plot(inver_Bpts6, Rint6+4500, label='-1.2Vg')
plt.plot(inver_Bpts7, Rint7+6000, label='-1.3Vg')
plt.plot(inver_Bpts8, Rint8+7500, label='-1.4Vg')
plt.plot(inver_Bpts9, Rint9+9000, label='-1.5Vg')
plt.plot(inver_Bpts10, Rint10+10500, label='-1.6Vg')
plt.plot(inver_Bpts11, Rint11+12000, label='-1.7Vg')
plt.plot(inver_Bpts12, Rint12+13500, label='-1.8Vg')
plt.plot(inver_Bpts13, Rint13+15000, label='-1.9Vg')
plt.plot(inver_Bpts14, Rint14+16500, label='-2.0Vg')
plt.plot(inver_Bpts15, Rint15+17000, label='-2.1Vg')
plt.plot(inver_Bpts16, Rint16+18000, label='-2.2Vg')
plt.axis((0.1, 1.6, -5000, 24500))
plt.xlabel('1/B')
plt.legend(loc='upper right')
# Out:
# <img src="data:image/png;base64,..." width="799.9999826604674">

# %%
m10, b10 = np.polyfit(inver_Bpts10, Rint10, 1)

plt.figure(figsize=(8, 6))
plt.plot(inver_Bpts10, Rint10, label='-1.6Vg')
x = np.linspace(0, 2.25, 100)
plt.plot(x, m10*x + b10)
plt.plot(inver_Bpts10, Rint10-m10*inver_Bpts10-b10, label='-1.6Vg')
plt.legend()
# Out:
# <img src="data:image/png;base64,..." width="799.9999826604674">

# %%
signalFFT2_sub = fft(Rint2-m2*inver_Bpts2-b2)
signalPSD2_sub = np.abs(signalFFT2_sub) ** 2
fftFreq2_sub = np.fft.fftfreq(len(signalPSD2_sub), abs(inver_Bpts2[1]-inver_Bpts2[0]))
i2_sub = fftFreq2_sub>0

signalFFT3_sub = fft(Rint3-m3*inver_Bpts3-b3)
signalPSD3_sub = np.abs(signalFFT3_sub) ** 2
fftFreq3_sub = np.fft.fftfreq(len(signalPSD3_sub), abs(inver_Bpts3[1]-inver_Bpts3[0]))
i3_sub = fftFreq3_sub>0

signalFFT5_sub = fft(Rint5-m5*inver_Bpts5-b5)
signalPSD5_sub = np.abs(signalFFT5_sub) ** 2
fftFreq5_sub = np.fft.fftfreq(len(signalPSD5_sub), abs(inver_Bpts5[1]-inver_Bpts5[0]))
i5_sub = fftFreq5_sub>0

signalFFT6_sub = fft(Rint6-m6*inver_Bpts6-b6)
signalPSD6_sub = np.abs(signalFFT6_sub) ** 2
fftFreq6_sub = np.fft.fftfreq(len(signalPSD6_sub), abs(inver_Bpts6[1]-inver_Bpts6[0]))
i6_sub = fftFreq6_sub>0

signalFFT7_sub = fft(Rint7-m7*inver_Bpts7-b7)
signalPSD7_sub = np.abs(signalFFT7_sub) ** 2
fftFreq7_sub = np.fft.fftfreq(len(signalPSD7_sub), abs(inver_Bpts7[1]-inver_Bpts7[0]))
i7_sub = fftFreq7_sub>0

signalFFT8_sub = fft(Rint8-m8*inver_Bpts8-b8)
signalPSD8_sub = np.abs(signalFFT8_sub) ** 2
fftFreq8_sub = np.fft.fftfreq(len(signalPSD8_sub), abs(inver_Bpts8[1]-inver_Bpts8[0]))
i8_sub = fftFreq8_sub>0

signalFFT9_sub = fft(Rint9-m9*inver_Bpts9-b9)
signalPSD9_sub = np.abs(signalFFT9_sub) ** 2
fftFreq9_sub = np.fft.fftfreq(len(signalPSD9_sub), abs(inver_Bpts9[1]-inver_Bpts9[0]))
i9_sub = fftFreq9_sub>0

signalFFT10_sub = fft(Rint10-m10*inver_Bpts10-b10)
signalPSD10_sub = np.abs(signalFFT10_sub) ** 2
fftFreq10_sub = np.fft.fftfreq(len(signalPSD10_sub), abs(inver_Bpts10[1]-inver_Bpts10[0]))
i10_sub = fftFreq10_sub>0

plt.figure(figsize=(8, 6))
plt.plot(fftFreq2_sub[i2_sub], signalPSD2_sub[i2_sub]/15-14e8, label='-0.8Vg');
plt.plot(fftFreq3_sub[i3_sub], signalPSD3_sub[i3_sub]/8-11.5e8, label='-0.9Vg');
plt.plot(fftFreq4_sub[i4_sub], signalPSD4_sub[i4_sub]/4-9.5e8, label='-1.0Vg');
plt.plot(fftFreq5_sub[i5_sub], signalPSD5_sub[i5_sub]/2-6.5e8, label='-1.1Vg');
plt.plot(fftFreq6_sub[i6_sub], signalPSD6_sub[i6_sub]-2.6e8, label='-1.2Vg');
plt.plot(fftFreq7_sub[i7_sub], signalPSD7_sub[i7_sub]*2, label='-1.3Vg');
plt.plot(fftFreq8_sub[i8_sub], signalPSD8_sub[i8_sub]*3+2e8, label='-1.4Vg');
plt.plot(fftFreq9_sub[i9_sub], signalPSD9_sub[i9_sub]*4+5e8, label='-1.5Vg');
plt.plot(fftFreq10_sub[i10_sub], signalPSD10_sub[i10_sub]*5+8e8, label='-1.6Vg');
plt.axis((0, 50, -15e8, 16e8))
# Out:
# <img src="data:image/png;base64,..." width="799.9999826604674">
# (0, 50, -1500000000.0, 1600000000.0)

# %%
#FFT and plot

signalFFTm1 = fft(Rintm1)
signalPSDm1 = np.abs(signalFFTm1) ** 2
fftFreqm1 = np.fft.fftfreq(len(signalPSDm1), (inver_Bptsm1[1]-inver_Bptsm1[0]))

signalFFT0 = fft(Rint0)
signalPSD0 = np.abs(signalFFT0) ** 2
fftFreq0 = np.fft.fftfreq(len(signalPSD0), (inver_Bpts0[1]-inver_Bpts0[0]))

signalFFT1 = fft(Rint1)
signalPSD1 = np.abs(signalFFT1) ** 2
fftFreq1 = np.fft.fftfreq(len(signalPSD1), (inver_Bpts1[1]-inver_Bpts1[0]))


signalFFT2 = fft(Rint2)
signalPSD2 = np.abs(signalFFT2) ** 2
fftFreq2 = np.fft.fftfreq(len(signalPSD2), abs(inver_Bpts2[1]-inver_Bpts2[0]))

signalFFT3 = fft(Rint3)
signalPSD3 = np.abs(signalFFT3) ** 2
fftFreq3 = np.fft.fftfreq(len(signalPSD3), abs(inver_Bpts3[1]-inver_Bpts3[0]))

signalFFT4 = fft(Rint4)
signalPSD4 = np.abs(signalFFT4) ** 2
fftFreq4 = np.fft.fftfreq(len(signalPSD4), abs(inver_Bpts4[1]-inver_Bpts4[0]))

signalFFT5 = fft(Rint5)
signalPSD5 = np.abs(signalFFT5) ** 2
fftFreq5 = np.fft.fftfreq(len(signalPSD5), abs(inver_Bpts5[1]-inver_Bpts5[0]))

signalFFT6 = fft(Rint6)
signalPSD6 = np.abs(signalFFT6) ** 2
fftFreq6 = np.fft.fftfreq(len(signalPSD6), abs(inver_Bpts6[1]-inver_Bpts6[0]))

signalFFT7 = fft(Rint7)
signalPSD7 = np.abs(signalFFT7) ** 2
fftFreq7 = np.fft.fftfreq(len(signalPSD7), abs(inver_Bpts7[1]-inver_Bpts7[0]))

signalFFT8 = fft(Rint8)
signalPSD8 = np.abs(signalFFT8) ** 2
fftFreq8 = np.fft.fftfreq(len(signalPSD8), abs(inver_Bpts8[1]-inver_Bpts8[0]))

signalFFT9 = fft(Rint9)
signalPSD9 = np.abs(signalFFT9) ** 2
fftFreq9 = np.fft.fftfreq(len(signalPSD9), abs(inver_Bpts9[1]-inver_Bpts9[0]))

signalFFT10 = fft(Rint10)
signalPSD10 = np.abs(signalFFT10) ** 2
fftFreq10 = np.fft.fftfreq(len(signalPSD10), abs(inver_Bpts10[1]-inver_Bpts10[0]))

signalFFT11 = fft(Rint11)
signalPSD11 = np.abs(signalFFT11) ** 2
fftFreq11 = np.fft.fftfreq(len(signalPSD11), abs(inver_Bpts11[1]-inver_Bpts11[0]))

signalFFT12 = fft(Rint12)
signalPSD12 = np.abs(signalFFT12) ** 2
fftFreq12 = np.fft.fftfreq(len(signalPSD12), abs(inver_Bpts12[1]-inver_Bpts12[0]))

signalFFT13 = fft(Rint13)
signalPSD13 = np.abs(signalFFT13) ** 2
fftFreq13 = np.fft.fftfreq(len(signalPSD13), abs(inver_Bpts13[1]-inver_Bpts13[0]))

signalFFT14 = fft(Rint14)
signalPSD14 = np.abs(signalFFT14) ** 2
fftFreq14 = np.fft.fftfreq(len(signalPSD14), abs(inver_Bpts14[1]-inver_Bpts14[0]))

signalFFT15 = fft(Rint15)
signalPSD15 = np.abs(signalFFT15) ** 2
fftFreq15 = np.fft.fftfreq(len(signalPSD15), abs(inver_Bpts15[1]-inver_Bpts15[0]))

signalFFT16 = fft(Rint16)
signalPSD16 = np.abs(signalFFT16) ** 2
fftFreq16 = np.fft.fftfreq(len(signalPSD16), abs(inver_Bpts16[1]-inver_Bpts16[0]))

im1 = fftFreqm1>0
i0 = fftFreq0>0
i1 = fftFreq1>0
i2 = fftFreq2>0
i3 = fftFreq3>0
i4 = fftFreq4>0
i5 = fftFreq5>0
i6 = fftFreq6>0
i7 = fftFreq7>0
i8 = fftFreq8>0
i9 = fftFreq9>0
i10 = fftFreq10>0
i11 = fftFreq11>0
i12 = fftFreq12>0
i13 = fftFreq13>0
i14 = fftFreq14>0
i15 = fftFreq15>0
i16 = fftFreq16>0
                       

plt.figure(figsize=(6, 9))
#plt.plot(fftFreqm1[im1], signalPSDm1[im1]-34e9,  label='-0.5Vg');
plt.plot(fftFreq0[i0], signalPSD0[i0]-19e9,  label='-0.6Vg');
plt.plot(fftFreq1[i1], signalPSD1[i1]-14e9,  label='-0.7Vg');
plt.plot(fftFreq2[i2], signalPSD2[i2]-6e9,  label='-0.8Vg');
plt.plot(fftFreq3[i3], signalPSD3[i3]*2.5-3e9, label='-0.9Vg');
plt.plot(fftFreq4[i4], signalPSD4[i4]*5+1e9, label='-1.0Vg');
plt.plot(fftFreq5[i5], signalPSD5[i5]*8+13e9, label='-1.1Vg');
plt.plot(fftFreq6[i6], signalPSD6[i6]+16e9, label='-1.2Vg');
plt.plot(fftFreq7[i7], signalPSD7[i7]+19e9, label='-1.3Vg');
plt.plot(fftFreq8[i8], signalPSD8[i8]+22e9, label='-1.4Vg');
plt.plot(fftFreq9[i9], signalPSD9[i9]+25e9, label='-1.5Vg');
plt.plot(fftFreq10[i10], signalPSD10[i10]+29e9, label='-1.6Vg');
plt.plot(fftFreq11[i11], signalPSD11[i11]+35e9, label='-1.7Vg');
plt.plot(fftFreq12[i12], signalPSD12[i12]+43e9, label='-1.8Vg');
#plt.plot(fftFreq13[i13], signalPSD13[i13]+50e9, label='-1.9Vg');
#plt.plot(fftFreq14[i14], signalPSD14[i14]+56e9, label='-2.0Vg');
#plt.plot(fftFreq15[i15], signalPSD15[i15]+61e9, label='-2.1Vg');
#plt.plot(fftFreq16[i16], signalPSD16[i16]+64e9, label='-2.2Vg');
plt.axis((0, 30, -20e9, 4.5e10))
plt.xlabel('frequency (T)')
plt.legend(loc='upper right')
# Out:
# <img src="data:image/png;base64,..." width="599.9999869953505">

# %%
datafan1=qc.load_data('data/2020-02-13/#003_W5_865_47-48_830_20-48_baseT_1nA_B-Vgsweep_11-01-44')
datafan2=qc.load_data('data/2020-02-15/#001_W5_865_47-48_830_20-48_baseT_1nA_B-Vgsweep_10-40-22')

# %%
fan1_field = datafan1.triton_field_set_stable_set[:126]
fan2_field = datafan2.triton_field_set_stable_set[:]
fan_field=np.concatenate((fan1_field,fan2_field))

# %%
fan_lockin865_X = np.concatenate((datafan1.lockin865_X[:126,:], datafan2.lockin865_X[:,:]), axis=0)

# %%
plt.figure(figsize=(11,6))
plt.pcolormesh(datafan1.srframe_volt_p1_set[0,:],fan_field[:],fan_lockin865_X[:,:]/1e-9,cmap='inferno',norm = colors.SymLogNorm(2000, vmin=-500, vmax=5e4))
# Out:
# <img src="data:image/png;base64,..." width="1099.9999761581425">

# %%
datafan3=qc.load_data('data/2020-04-19/#001_W3_865_48-24_830_47-48_5K_10nA_B-Vg2D_emerging_state_11-17-02')
datafan4=qc.load_data('data/2020-04-20/#001_W3_865_48-24_830_47-48_5K_10nA_B-Vg2D_emerging_state_11-22-40')

# %%
fan1_field = datafan3.triton_field_set_stable_set[:52]
fan2_field = datafan4.triton_field_set_stable_set[:]
fan_field=np.concatenate((fan3_field,fan4_field))

# %%
fan_lockin865_X = np.concatenate((datafan3.lockin865_X[:52,:], datafan4.lockin865_X[:,:]), axis=0)

# %%
plt.figure(figsize=(10,6))
plt.pcolormesh(datafan3.srframe_volt_p1_set[0,:181],fan_field[:],fan_lockin865_X[:,:181]/10e-9,cmap='inferno',norm = colors.SymLogNorm(9000, vmin=-500, vmax=1e4))
# Out:
# <img src="data:image/png;base64,..." width="999.9999783255842">

# %%
datafan5=qc.load_data('data/2020-04-18/#001_W3_865_48-24_830_47-48_1K_10nA_B-Vg2D_emerging_state_13-18-34')

# %%
plt.figure(figsize=(10,6))
plt.pcolormesh(datafan5.srframe_volt_p1_set[0,:181],datafan5.triton_field_set_stable_set[:],datafan5.lockin865_X[:,:181]/10e-9,cmap='inferno',norm = colors.SymLogNorm(5000, vmin=-500, vmax=1e4))
# Out:
# <img src="data:image/png;base64,..." width="999.9999783255842">

# %%
datafan6=qc.load_data('data/2020-04-17/#004_W3_865_48-24_830_47-48_baseT_10nA_B-Vg2D_emerging_state_15-13-06')

# %%
plt.figure(figsize=(10,6))
plt.pcolormesh(datafan6.srframe_volt_p1_set[0,20:],datafan6.triton_field_set_stable_set[:],datafan6.lockin865_X[:,20:]/10e-9,cmap='inferno',norm = colors.SymLogNorm(5000, vmin=-500, vmax=1e4))
# Out:
# <img src="data:image/png;base64,..." width="999.9999783255842">
