# %%
import numpy as np
import time
import matplotlib.pyplot as plt
import qcodes as qc
import qcodes.instrument_drivers.nplab_drivers as npd

# %%
# %matplotlib notebook

# %%
npd.triton_init('lockin865', 'lockin830', 'srframe')
# Out:
# Connected to: OXFORD INSTRUMENTS Triton (serial:N/A, firmware:2.449) in 0.01s
# Connected to: Stanford_Research_Systems SR865A (serial:003538, firmware:V1.51) in 0.11s
# Connected to: Stanford_Research_Systems SR830 (serial:s/n49840, firmware:ver1.07) in 0.05s
# Connected to: Stanford_Research_Systems SIM900 (serial:s/n152150, firmware:ver3.6) in 0.75s

# %%
srframe.volt_p1.step = 0.08
srframe.volt_p1.inter_delay = 0.1
srframe.volt_p5.step = 0.08
srframe.volt_p5.inter_delay = 0.1

# %% [markdown]
# # Systematic study of M10 contact uniformity and quantization

# %%
srframe.volt_p1(-18)
time.sleep(10)
gvals = np.linspace(-18, 18, 361)
data1, plot1 = npd.single_param_sweep(srframe.volt_p1, gvals, 1.3, lockin865.X, lockin865.Y, lockin830.X, lockin830.Y, DataName='M10_29-2_865_2-3_830_basetemp_0T_sensorsdisconnected_2nA')
srframe.volt_p1(0)

g2_3 = data1.srframe_volt_p1_set[:]
R2_3 = data1.lockin830_X[:]/2e-9
plt.figure(figsize=(8,5))
plt.semilogy(g2_3, np.abs(R2_3),label='2-3')

g29_2 = data1.srframe_volt_p1_set[:]
R29_2 = data1.lockin865_X[:]/2e-9
plt.semilogy(g29_2, np.abs(R29_2),label='29-2')
plt.legend()
# Out:
# Started at 2019-11-15 12:30:57
# DataSet:
#    location = 'data/2019-11-15/#002_M10_29-2_865_2-3_830_basetemp_0T_sensorsdisconnected_2nA_12-30-53'
#    <Type>   | <array_id>          | <array.name> | <array.shape>
#    Setpoint | srframe_volt_p1_set | volt_p1      | (361,)
#    Measured | lockin865_X         | X            | (361,)
#    Measured | lockin865_Y         | Y            | (361,)
#    Measured | lockin830_X         | X            | (361,)
#    Measured | lockin830_Y         | Y            | (361,)
# Finished at 2019-11-15 12:40:50
# <img src="data:image/png;base64,..." width="800">

# %%
srframe.volt_p1(-18)
time.sleep(10)
gvals = np.linspace(-18, 18, 361)
data2, plot2 = npd.single_param_sweep(srframe.volt_p1, gvals, 1, lockin865.X, lockin865.Y, lockin830.X, lockin830.Y, DataName='M10_3-8_865_7-8_830_basetemp_0T_sensorsdisconnected_2nA')
srframe.volt_p1(0)

g7_8 = data2.srframe_volt_p1_set[:]
R7_8 = data2.lockin830_X[:]/2e-9
plt.figure(figsize=(8,5))
plt.semilogy(g7_8, np.abs(R7_8),label='7-8')

g3_8 = data2.srframe_volt_p1_set[:]
R3_8 = data2.lockin865_X[:]/2e-9
plt.semilogy(g3_8, np.abs(R3_8),label='3-8')
plt.legend()
# Out:
# Started at 2019-11-15 12:43:27
# DataSet:
#    location = 'data/2019-11-15/#003_M10_3-8_865_7-8_830_basetemp_0T_sensorsdisconnected_2nA_12-43-25'
#    <Type>   | <array_id>          | <array.name> | <array.shape>
#    Setpoint | srframe_volt_p1_set | volt_p1      | (361,)
#    Measured | lockin865_X         | X            | (361,)
#    Measured | lockin865_Y         | Y            | (361,)
#    Measured | lockin830_X         | X            | (361,)
#    Measured | lockin830_Y         | Y            | (361,)
# Finished at 2019-11-15 12:51:30
# <img src="data:image/png;base64,..." width="800">

# %%
plt.figure(figsize=(8,5))
plt.semilogy(g29_2, np.abs(R29_2),label='29-2')
plt.semilogy(g2_3, np.abs(R2_3),label='2-3')
plt.semilogy(g3_8, np.abs(R3_8),label='3-8')
plt.legend()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
srframe.volt_p1(-18)
time.sleep(10)
gvals = np.linspace(-18, 18, 361)
data3, plot3 = npd.single_param_sweep(srframe.volt_p1, gvals, 1, lockin865.X, lockin865.Y, lockin830.X, lockin830.Y, DataName='M10_26-25_865_25-4_830_basetemp_0T_sensorsdisconnected_2nA')
srframe.volt_p1(0)

g26_25 = data3.srframe_volt_p1_set[:]
R26_25 = data3.lockin830_X[:]/2e-9
plt.figure(figsize=(8,5))
plt.semilogy(g26_25, np.abs(R26_25),label='26-25')

g25_4 = data3.srframe_volt_p1_set[:]
R25_4 = data3.lockin865_X[:]/2e-9
plt.semilogy(g25_4, np.abs(R25_4),label='25-4')
plt.legend()
# Out:
# Started at 2019-11-15 13:18:08
# DataSet:
#    location = 'data/2019-11-15/#004_M10_26-25_865_25-4_830_basetemp_0T_sensorsdisconnected_2nA_13-18-06'
#    <Type>   | <array_id>          | <array.name> | <array.shape>
#    Setpoint | srframe_volt_p1_set | volt_p1      | (361,)
#    Measured | lockin865_X         | X            | (361,)
#    Measured | lockin865_Y         | Y            | (361,)
#    Measured | lockin830_X         | X            | (361,)
#    Measured | lockin830_Y         | Y            | (361,)
# Finished at 2019-11-15 13:26:11
# <img src="data:image/png;base64,..." width="800">

# %%
srframe.volt_p1(-18)
time.sleep(10)
gvals = np.linspace(-18, 18, 361)
data4, plot4 = npd.single_param_sweep(srframe.volt_p1, gvals, 1, lockin865.X, lockin865.Y, DataName='M10_4-5_865_basetemp_0T_sensorsdisconnected_2nA')
srframe.volt_p1(0)

g4_5 = data4.srframe_volt_p1_set[:]
R4_5 = data4.lockin830_X[:]/2e-9
plt.figure(figsize=(8,5))
plt.semilogy(g4_5, np.abs(R4_5),label='4-5')
# Out:
# Started at 2019-11-15 13:32:36
# DataSet:
#    location = 'data/2019-11-15/#005_M10_4-5_865_basetemp_0T_sensorsdisconnected_2nA_13-32-35'
#    <Type>   | <array_id>          | <array.name> | <array.shape>
#    Setpoint | srframe_volt_p1_set | volt_p1      | (361,)
#    Measured | lockin865_X         | X            | (361,)
#    Measured | lockin865_Y         | Y            | (361,)
# Finished at 2019-11-15 13:40:13
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-b534d2f84923> in <module>
#       6
#       7 g4_5 = data4.srframe_volt_p1_set[:]
# ----> 8 R4_5 = data4.lockin830_X[:]/2e-9
#       9 plt.figure(figsize=(8,5))
#      10 plt.semilogy(g4_5, np.abs(R4_5),label='4-5')
#
# c:\users\nplab\documents\qcodes\qcodes\utils\helpers.py in __getattr__(self, key)
#     431         raise AttributeError(
# ...

# %%
g4_5 = data4.srframe_volt_p1_set[:]
R4_5 = data4.lockin865_X[:]/2e-9
plt.figure(figsize=(8,5))
plt.semilogy(g4_5, np.abs(R4_5),label='4-5')
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
plt.figure(figsize=(8,5))
plt.semilogy(g29_2, np.abs(R29_2),label='29-2')
plt.semilogy(g2_3, np.abs(R2_3),label='2-3')
plt.semilogy(g3_8, np.abs(R3_8),label='3-8')
plt.semilogy(g26_25, np.abs(R26_25),label='26-25')
plt.semilogy(g25_4, np.abs(R25_4),label='25-4')
plt.legend()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %% [markdown]
# # Rxy measurement on 26-29 and 25-2

# %%
gvals = np.linspace(-15, 15, 601)
bvals = np.linspace(8, 0, 81)
data5, plot5 = npd.twod_param_sweep(triton.field_set_stable, bvals, srframe.volt_p1, gvals, lockin865.X, lockin865.Y, lockin830.X, lockin830.Y, SetDelay1=8, SetDelay2=0.85, DataName='M10_26_29_865and25_2_830_8Tto0T_2nA')
srframe.volt_p5(0)
srframe.volt_p1(0)
# Out:
# Started at 2019-11-15 13:56:51
# Are you sure you want to use the magnet? [y/n]: y
# Please wait 4810.03 seconds for the field sweep, plus the time required for operating the switch...
# Please wait 70.006 seconds for the field sweep, plus the time required for operating the switch...
# Please wait 70.0 seconds for the field sweep, plus the time required for operating the switch...
# Please wait 70.006 seconds for the field sweep, plus the time required for operating the switch...
# Please wait 70.006 seconds for the field sweep, plus the time required for operating the switch...
# Please wait 70.0 seconds for the field sweep, plus the time required for operating the switch...
# Please wait 70.006 seconds for the field sweep, plus the time required for operating the switch...
# Please wait 70.006 seconds for the field sweep, plus the time required for operating the switch...
# Please wait 70.0 seconds for the field sweep, plus the time required for operating the switch...
# ...

# %% [markdown]
# # Magnet quenched at around 5T

# %%
triton.magnet_temp()
# Out:
# 4.31793

# %%
triton.field()
# Out:
# 0.0

# %%
plot5[0]

# %%
plot5[2]

# %%
triton.magnet_temp()
# Out:
# 4.31682

# %%
gvals = np.linspace(-15, 15, 601)
bvals = np.linspace(5.5, 0, 56)
data6, plot6 = npd.twod_param_sweep(triton.field_set_stable, bvals, srframe.volt_p1, gvals, lockin865.X, lockin865.Y, lockin830.X, lockin830.Y, SetDelay1=8, SetDelay2=0.85, DataName='M10_26_29_865and25_2_830_5.5Tto0T_2nA')
srframe.volt_p5(0)
srframe.volt_p1(0)
# Out:
# Started at 2019-11-17 14:28:46
# Are you sure you want to use the magnet? [y/n]: y
# Please wait 3310.324 seconds for the field sweep, plus the time required for operating the switch...
# Please wait 70.012 seconds for the field sweep, plus the time required for operating the switch...
# Please wait 70.0 seconds for the field sweep, plus the time required for operating the switch...
# Please wait 69.994 seconds for the field sweep, plus the time required for operating the switch...
# Please wait 70.006 seconds for the field sweep, plus the time required for operating the switch...
# Please wait 70.012 seconds for the field sweep, plus the time required for operating the switch...
# Please wait 70.006 seconds for the field sweep, plus the time required for operating the switch...
# Please wait 70.012 seconds for the field sweep, plus the time required for operating the switch...
# Please wait 70.006 seconds for the field sweep, plus the time required for operating the switch...
# ...

# %%
plot6[0]

# %%
plot6[2]

# %%
gvals = np.linspace(-10, 1, 221)
bvals = np.linspace(0, -6, 61)
data7, plot7 = npd.twod_param_sweep(triton.field_set_stable, bvals, srframe.volt_p1, gvals, lockin865.X, lockin865.Y, lockin830.X, lockin830.Y, SetDelay1=8, SetDelay2=0.9, DataName='M10_26_29_865and25_2_830_0to-5.5T_-10to1Vgate_2nA')
srframe.volt_p5(0)
srframe.volt_p1(0)
triton.field(0)

# %%
plot7[0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-06b15c01b83b> in <module>
# ----> 1 plot7[0]
#
# NameError: name 'plot7' is not defined

# %%
def multipoints(arr, samples):
    samples = int(samples)
    newa = []
    for i in arr:
        for j in range(samples):
            newa.append(i)
    
    return np.array(newa)

exa = np.linspace(0.5, 5, 451)
newa = multipoints(exa, 3)

gvals = newa
bvals = np.linspace(-7, 0, 141)
data8, plot8 = npd.twod_param_sweep(triton.field_set_stable, bvals, srframe.volt_p1, gvals, lockin865.X, lockin865.Y, lockin865.R, lockin830.X, lockin830.Y, lockin830.R, SetDelay1=8, SetDelay2=0.9, DataName='M12_12_22_830and20_13_865_-7Tto0T_0.5to5Vgate_5nA_avg3')
srframe.volt_p5(0)
srframe.volt_p1(0)
# Out:
# Started at 2019-11-18 14:56:52
# Please wait 10.006 seconds for the field sweep, plus the time required for operating the switch...
# c:\users\nplab\documents\qcodes\qcodes\plots\pyqtgraph.py:409: UserWarning: nonlinear setpoint array passed to pyqtgraph. ignoring, using default scaling.
#   warnings.warn('nonlinear setpoint array passed to pyqtgraph. '
# c:\users\nplab\documents\qcodes\qcodes\plots\pyqtgraph.py:409: UserWarning: nonlinear setpoint array passed to pyqtgraph. ignoring, using default scaling.
#   warnings.warn('nonlinear setpoint array passed to pyqtgraph. '
# c:\users\nplab\documents\qcodes\qcodes\plots\pyqtgraph.py:409: UserWarning: nonlinear setpoint array passed to pyqtgraph. ignoring, using default scaling.
#   warnings.warn('nonlinear setpoint array passed to pyqtgraph. '
# c:\users\nplab\documents\qcodes\qcodes\plots\pyqtgraph.py:409: UserWarning: nonlinear setpoint array passed to pyqtgraph. ignoring, using default scaling.
# ...

# %%
triton.magnet_swh(0)
# Out:
# Wait 5 min for the switch to cool

# %% [markdown]
# # -8T persisient magnet gate sweeps for different contacts, M12 first

# %% [markdown]
# Contacts 13 and 20 on 865 and 12 and 22 on 830

# %%
srframe.volt_p1(0.5)
time.sleep(10)
gvals = np.linspace(0.5, 5, 451)
data9, plot9 = npd.single_param_sweep(srframe.volt_p1, gvals, 1.5, lockin865.X, lockin865.Y, lockin865.R, lockin830.X, lockin830.Y, lockin830.R, DataName='M12_13-20_865_12-22_830_basetemp_0T_sensorsdisconnected_20nA')
srframe.volt_p1(0)

g13_20 = data9.srframe_volt_p1_set[:]
R13_20 = data9.lockin865_R[:]/20e-9
plt.figure(figsize=(8,5))
plt.semilogy(g13_20, np.abs(R13_20),label='13-20')

g12_22 = data9.srframe_volt_p1_set[:]
R12_22 = data9.lockin830_R[:]/20e-9
plt.semilogy(g12_22, np.abs(R12_22),label='12-22')
plt.legend()
# Out:
# Started at 2019-11-19 13:41:59
# DataSet:
#    location = 'data/2019-11-19/#003_M12_13-20_865_12-22_830_basetemp_0T_sensorsdisconnected_20nA_13-41-55'
#    <Type>   | <array_id>          | <array.name> | <array.shape>
#    Setpoint | srframe_volt_p1_set | volt_p1      | (451,)
#    Measured | lockin865_X         | X            | (451,)
#    Measured | lockin865_Y         | Y            | (451,)
#    Measured | lockin865_R         | R            | (451,)
#    Measured | lockin830_X         | X            | (451,)
#    Measured | lockin830_Y         | Y            | (451,)
#    Measured | lockin830_R         | R            | (451,)
# Finished at 2019-11-19 13:55:08
# <img src="data:image/png;base64,..." width="800">

# %%
srframe.volt_p1(4)
time.sleep(15)
gvals = np.linspace(4, 4.5, 51)
data10, plot10 = npd.single_param_sweep(srframe.volt_p1, gvals, 6, lockin865.X, lockin865.Y, lockin865.R, lockin830.X, lockin830.Y, lockin830.R, DataName='M12_13-20_865_12-22_830_basetemp_0T_sensorsdisconnected_20nA_zoominaround4V')
srframe.volt_p1(0)

g13_20_2 = data10.srframe_volt_p1_set[:]
R13_20_2 = data10.lockin865_R[:]/20e-9
plt.figure(figsize=(8,5))
plt.semilogy(g13_20_2, np.abs(R13_20_2),label='13-20')

g12_22_2 = data10.srframe_volt_p1_set[:]
R12_22_2 = data10.lockin830_R[:]/20e-9
plt.semilogy(g12_22_2, np.abs(R12_22_2),label='12-22')
plt.legend()
# Out:
# Started at 2019-11-19 13:58:44
# DataSet:
#    location = 'data/2019-11-19/#004_M12_13-20_865_12-22_830_basetemp_0T_sensorsdisconnected_20nA_zoominaround4V_13-58-42'
#    <Type>   | <array_id>          | <array.name> | <array.shape>
#    Setpoint | srframe_volt_p1_set | volt_p1      | (51,)
#    Measured | lockin865_X         | X            | (51,)
#    Measured | lockin865_Y         | Y            | (51,)
#    Measured | lockin865_R         | R            | (51,)
#    Measured | lockin830_X         | X            | (51,)
#    Measured | lockin830_Y         | Y            | (51,)
#    Measured | lockin830_R         | R            | (51,)
# Finished at 2019-11-19 14:04:03
# <img src="data:image/png;base64,..." width="800">

# %%
srframe.volt_p1(0.5)
time.sleep(10)
gvals = np.linspace(0.5, 5, 451)
data11, plot11 = npd.single_param_sweep(srframe.volt_p1, gvals, 2, lockin865.X, lockin865.Y, lockin865.R, lockin830.X, lockin830.Y, lockin830.R, DataName='M12_13-20_865_12-22_830_basetemp_0T_sensorsdisconnected_20nA_magnetsensortoo')
srframe.volt_p1(0)

g13_20_3 = data11.srframe_volt_p1_set[:]
R13_20_3 = data11.lockin865_R[:]/20e-9
plt.figure(figsize=(8,5))
plt.semilogy(g13_20_3, np.abs(R13_20_3),label='13-20')

g12_22_3 = data11.srframe_volt_p1_set[:]
R12_22_3 = data11.lockin830_R[:]/20e-9
plt.semilogy(g12_22_3, np.abs(R12_22_3),label='12-22')
plt.legend()
# Out:
# Started at 2019-11-19 14:06:41
# DataSet:
#    location = 'data/2019-11-19/#005_M12_13-20_865_12-22_830_basetemp_0T_sensorsdisconnected_20nA_magnetsensortoo_14-06-38'
#    <Type>   | <array_id>          | <array.name> | <array.shape>
#    Setpoint | srframe_volt_p1_set | volt_p1      | (451,)
#    Measured | lockin865_X         | X            | (451,)
#    Measured | lockin865_Y         | Y            | (451,)
#    Measured | lockin865_R         | R            | (451,)
#    Measured | lockin830_X         | X            | (451,)
#    Measured | lockin830_Y         | Y            | (451,)
#    Measured | lockin830_R         | R            | (451,)
# Finished at 2019-11-19 14:23:44
# <img src="data:image/png;base64,..." width="783">

# %%
plt.figure(figsize=(8,5))
plt.plot(g12_22_3, np.abs(1/R12_22_3),label='12-22_magnet_sensor_disconnected')
plt.plot(g12_22, np.abs(1/R12_22),label='12-22')
plt.legend()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
srframe.volt_p1(0.5)
time.sleep(10)
gvals = np.linspace(0.5, 5, 451)
data12, plot12 = npd.single_param_sweep(srframe.volt_p1, gvals, 2, lockin865.X, lockin865.Y, lockin865.R, lockin830.X, lockin830.Y, lockin830.R, DataName='M12_13-12_865_20-22_830_basetemp_0T_sensorsdisconnected_20nA_magnetsensortoo')
srframe.volt_p1(0)
# Out:
# Started at 2019-11-19 14:32:30
# DataSet:
#    location = 'data/2019-11-19/#006_M12_13-12_865_20-22_830_basetemp_0T_sensorsdisconnected_20nA_magnetsensortoo_14-32-28'
#    <Type>   | <array_id>          | <array.name> | <array.shape>
#    Setpoint | srframe_volt_p1_set | volt_p1      | (451,)
#    Measured | lockin865_X         | X            | (451,)
#    Measured | lockin865_Y         | Y            | (451,)
#    Measured | lockin865_R         | R            | (451,)
#    Measured | lockin830_X         | X            | (451,)
#    Measured | lockin830_Y         | Y            | (451,)
#    Measured | lockin830_R         | R            | (451,)
# Finished at 2019-11-19 14:49:24
# <div id='6a6383dc-0d20-4636-ae9c-20c82b67a4e4'></div>
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-70ad7b5e6abf> in <module>
#       8 R12_13 = data12.lockin865_R[:]/20e-9
# ...

# %%
g12_13 = data12.srframe_volt_p1_set[:]
R12_13 = data12.lockin865_R[:]/20e-9
plt.figure(figsize=(8,5))
plt.semilogy(g12_13, np.abs(R12_13),label='13-12')

g20_22 = data12.srframe_volt_p1_set[:]
R20_22 = data12.lockin830_R[:]/20e-9
plt.semilogy(g20_22, np.abs(R20_22),label='20-22')
plt.legend()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
gvals = np.linspace(-5, 5, 1001)
bvals = np.linspace(-8, -6, 21)
data13, plot13 = npd.twod_param_sweep(triton.field_set_stable, bvals, srframe.volt_p1, gvals, lockin865.X, lockin865.Y, lockin865.R, lockin830.X, lockin830.Y, lockin830.R, SetDelay1=10, SetDelay2=2.4, DataName='M12_13_12_865and22_12_830_-8Tto-6T_20nA')
srframe.volt_p5(0)
srframe.volt_p1(0)
# Out:
# Started at 2019-11-19 15:00:13
# Are you sure you want to use the magnet? [y/n]: y
# Please wait 10.0 seconds for the field sweep, plus the time required for operating the switch...
# Please wait 50.001999999999995 seconds for the field sweep, plus the time required for operating the switch...
# Please wait 50.001999999999995 seconds for the field sweep, plus the time required for operating the switch...
# Please wait 49.995999999999995 seconds for the field sweep, plus the time required for operating the switch...
# Please wait 50.007999999999996 seconds for the field sweep, plus the time required for operating the switch...
# Please wait 50.001999999999995 seconds for the field sweep, plus the time required for operating the switch...
# Please wait 49.995999999999995 seconds for the field sweep, plus the time required for operating the switch...
# Please wait 49.995999999999995 seconds for the field sweep, plus the time required for operating the switch...
# ...

# %%
gvals = np.linspace(-5, 5, 1001)
bvals = np.linspace(-5.9, -5, 10)
data14, plot14 = npd.twod_param_sweep(triton.field_set_stable, bvals, srframe.volt_p1, gvals, lockin865.X, lockin865.Y, lockin865.R, lockin830.X, lockin830.Y, lockin830.R, SetDelay1=10, SetDelay2=2.4, DataName='M12_13_12_865and22_12_830_-5.9Tto-5T_20nA')
srframe.volt_p5(0)
srframe.volt_p1(0)
# Out:
# Started at 2019-11-20 11:27:00
# Please wait 50.001999999999995 seconds for the field sweep, plus the time required for operating the switch...
# Please wait 50.001999999999995 seconds for the field sweep, plus the time required for operating the switch...
# Please wait 49.984 seconds for the field sweep, plus the time required for operating the switch...
# Please wait 49.995999999999995 seconds for the field sweep, plus the time required for operating the switch...
# Please wait 50.007999999999996 seconds for the field sweep, plus the time required for operating the switch...
# DataSet:
#    location = 'data/2019-11-20/#001_M12_13_12_865and22_12_830_-5.9Tto-5T_20nA_11-26-56'
#    <Type>   | <array_id>                  | <array.name>     | <array.shape>
#    Setpoint | triton_field_set_stable_set | field_set_stable | (10,)
#    Setpoint | srframe_volt_p1_set         | volt_p1          | (10, 1001)
#    Measured | lockin865_X                 | X                | (10, 1001)
# ...

# %%
gvals = np.linspace(-7.5, 7.5, 1501)
bvals = np.linspace(8, 6, 21)
data15, plot15 = npd.twod_param_sweep(triton.field_set_stable, bvals, srframe.volt_p1, gvals, lockin865.X, lockin865.Y, lockin865.R, lockin830.X, lockin830.Y, lockin830.R, SetDelay1=10, SetDelay2=2, DataName='M10_26_25_865and26_29_830_-8Tto-6T_20nA')
srframe.volt_p5(0)
srframe.volt_p1(0)
# Out:
# Started at 2019-11-20 18:23:22
# Please wait 10.006 seconds for the field sweep, plus the time required for operating the switch...
# Please wait 49.995999999999995 seconds for the field sweep, plus the time required for operating the switch...
# Please wait 50.007999999999996 seconds for the field sweep, plus the time required for operating the switch...
# Please wait 50.001999999999995 seconds for the field sweep, plus the time required for operating the switch...
# Please wait 50.001999999999995 seconds for the field sweep, plus the time required for operating the switch...
# Please wait 50.007999999999996 seconds for the field sweep, plus the time required for operating the switch...
# Please wait 49.995999999999995 seconds for the field sweep, plus the time required for operating the switch...
# Please wait 49.995999999999995 seconds for the field sweep, plus the time required for operating the switch...
# ...

# %%
triton.field()
# Out:
# 7.999986

# %%
triton.field()
# Out:
# 7.999986

# %%
triton.magnet_swh()
# Out:
# 0

# %%
triton.field(8)
# Out:
# Sweep time approximately 610.0 seconds

# %%
srframe.volt_p1(-8)
time.sleep(10)
gvals = np.linspace(-8, 8, 321)
data16, plot16 = npd.single_param_sweep(srframe.volt_p1, gvals, 1, lockin865.X, lockin865.Y, lockin865.R, DataName='M10_26-29_865_basetemp_8T_sensorsdisconnected_2nA')
srframe.volt_p1(0)

g26_29_8T = data16.srframe_volt_p1_set[:]
R26_29_8T = data16.lockin865_X[:]/2e-9
plt.figure(figsize=(8,5))
plt.plot(g26_29_8T, (R26_29_8T),label='26-29_8T')
# Out:
# Started at 2019-11-21 13:36:32
# DataSet:
#    location = 'data/2019-11-21/#001_M10_26-29_865_basetemp_8T_sensorsdisconnected_2nA_13-36-31'
#    <Type>   | <array_id>          | <array.name> | <array.shape>
#    Setpoint | srframe_volt_p1_set | volt_p1      | (321,)
#    Measured | lockin865_X         | X            | (321,)
#    Measured | lockin865_Y         | Y            | (321,)
#    Measured | lockin865_R         | R            | (321,)
# Finished at 2019-11-21 13:42:39
# <img src="data:image/png;base64,..." width="800">
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-a58f1aa01ca1> in <module>
#       8 R26_29_8T = data16.lockin865_X[:]/2e-9
#       9 plt.figure(figsize=(8,5))
# ---> 10 plt.plot(g26_29, (R26_29_8T),label='26-29_8T')
#
# NameError: name 'g26_29' is not defined

# %%
g26_29_8T = data16.srframe_volt_p1_set[:]
R26_29_8T = data16.lockin865_R[:]/2e-9
plt.figure(figsize=(8,5))
plt.semilogy(g26_29_8T, np.abs(R26_29_8T),label='26-29_8T')
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
srframe.volt_p1(-8)
time.sleep(10)
gvals = np.linspace(-8, 8, 321)
data17, plot17 = npd.single_param_sweep(srframe.volt_p1, gvals, 1, lockin865.X, lockin865.Y, lockin865.R, DataName='M10_4-8_865_basetemp_8T_sensorsdisconnected_2nA')
srframe.volt_p1(0)

g4_8_8T = data17.srframe_volt_p1_set[:]
R4_8_8T = data17.lockin865_R[:]/2e-9
plt.figure(figsize=(8,5))
plt.semilogy(g4_8_8T, np.abs(R4_8_8T),label='4-8_8T')
# Out:
# Started at 2019-11-21 14:27:19
# DataSet:
#    location = 'data/2019-11-21/#002_M10_4-8_865_basetemp_8T_sensorsdisconnected_2nA_14-27-18'
#    <Type>   | <array_id>          | <array.name> | <array.shape>
#    Setpoint | srframe_volt_p1_set | volt_p1      | (321,)
#    Measured | lockin865_X         | X            | (321,)
#    Measured | lockin865_Y         | Y            | (321,)
#    Measured | lockin865_R         | R            | (321,)
# Finished at 2019-11-21 14:33:26
# <img src="data:image/png;base64,..." width="800">

# %%
lockin865.time_constant(0.3)
lockin865.filter_slope(12)
lockin865.amplitude(50e-3)
srframe.volt_p1(-8)  #same but try this time with lower current excitation, more averaging (0.5 nA)
time.sleep(10)
gvals = np.linspace(-8, 8, 321)
data18, plot18 = npd.single_param_sweep(srframe.volt_p1, gvals, 2.1, lockin865.X, lockin865.Y, lockin865.R, DataName='M10_4-8_865_basetemp_8T_sensorsdisconnected_0.5nA')
srframe.volt_p1(0)
# Out:
# Started at 2019-11-21 14:36:23
# DataSet:
#    location = 'data/2019-11-21/#003_M10_4-8_865_basetemp_8T_sensorsdisconnected_0.5nA_14-36-22'
#    <Type>   | <array_id>          | <array.name> | <array.shape>
#    Setpoint | srframe_volt_p1_set | volt_p1      | (321,)
#    Measured | lockin865_X         | X            | (321,)
#    Measured | lockin865_Y         | Y            | (321,)
#    Measured | lockin865_R         | R            | (321,)
# Finished at 2019-11-21 14:48:23

# %%
g4_8_8T_p5 = data18.srframe_volt_p1_set[:]
R4_8_8T_p5 = data18.lockin865_R[:]/0.5e-9
plt.figure(figsize=(8,5))
plt.semilogy(g4_8_8T, np.abs(R4_8_8T),label='4-8-29_8T_2nA')
plt.semilogy(g4_8_8T_p5, np.abs(R4_8_8T_p5),label='4-8_8T_0.5nA')
plt.legend()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
lockin865.time_constant(0.1)
lockin865.filter_slope(24)
lockin865.amplitude(100e-3)
srframe.volt_p1(-8)  #different electrodes, this time 1 nA
time.sleep(10)
gvals = np.linspace(-8, 8, 321)
data19, plot19 = npd.single_param_sweep(srframe.volt_p1, gvals, 1.15, lockin865.X, lockin865.Y, lockin865.R, DataName='M10_25-2_865_basetemp_8T_sensorsdisconnected_1nA')
srframe.volt_p1(0)
# Out:
# Started at 2019-11-21 14:59:31
# DataSet:
#    location = 'data/2019-11-21/#004_M10_25-2_865_basetemp_8T_sensorsdisconnected_1nA_14-59-30'
#    <Type>   | <array_id>          | <array.name> | <array.shape>
#    Setpoint | srframe_volt_p1_set | volt_p1      | (321,)
#    Measured | lockin865_X         | X            | (321,)
#    Measured | lockin865_Y         | Y            | (321,)
#    Measured | lockin865_R         | R            | (321,)
# Finished at 2019-11-21 15:06:25

# %%
g25_2_8T = data19.srframe_volt_p1_set[:]
R25_2_8T = data19.lockin865_R[:]/1e-9
plt.figure(figsize=(8,5))
plt.semilogy(g25_2_8T, np.abs(R25_2_8T))
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
srframe.volt_p1(-8)
time.sleep(10)
gvals = np.linspace(-8, 8, 321)
data20, plot20 = npd.single_param_sweep(srframe.volt_p1, gvals, 1.15, lockin865.X, lockin865.Y, lockin865.R, DataName='M10_5-7_865_basetemp_8T_sensorsdisconnected_1nA')
srframe.volt_p1(0)
# Out:
# Started at 2019-11-21 15:44:11
# DataSet:
#    location = 'data/2019-11-21/#006_M10_5-7_865_basetemp_8T_sensorsdisconnected_1nA_15-44-10'
#    <Type>   | <array_id>          | <array.name> | <array.shape>
#    Setpoint | srframe_volt_p1_set | volt_p1      | (321,)
#    Measured | lockin865_X         | X            | (321,)
#    Measured | lockin865_Y         | Y            | (321,)
#    Measured | lockin865_R         | R            | (321,)
# Finished at 2019-11-21 15:51:06

# %%
g5_7_8T = data20.srframe_volt_p1_set[:]
Rxy5_7_8T = data20.lockin865_R[:]/1e-9

# %%
esqh = 1.602e-19**2/6.626e-34

# %%
plt.figure()
plt.plot(g26_29_8T, 1/R26_29_8T/esqh,label='26-29_8T_2nA')
plt.plot(g26_29_8T_1n, 1/R26_29_8T_1n/esqh, label='26-29_8T_1nA')
plt.plot(g26_29_8T_p1n, 1/R26_29_8T_p1n/esqh, label='26-29_8T_0.1nA')
# plt.plot(g25_2_8T, 1/R25_2_8T/esqh, label='25-2_8T_1nA')
# plt.plot(g4_8_8T_p5, 1/R4_8_8T_p5/esqh,label='4-8_8T_0.5nA')
# plt.plot(g4_8_8T, 1/R4_8_8T/esqh,label='4-8-29_8T_2nA')
# plt.plot(g5_7_8T, 1/Rxy5_7_8T/esqh, label='5-7_8T_1nA')
plt.legend()
plt.ylim((-15, 15))
# Out:
# <img src="data:image/png;base64,..." width="779">
# (-15, 15)

# %%
srframe.volt_p1(-8)  # try again on 26-29 to see if better wait times take the noise away
time.sleep(10)
gvals = np.linspace(-8, 8, 321)
data21, plot21 = npd.single_param_sweep(srframe.volt_p1, gvals, 1.25, lockin865.X, lockin865.Y, lockin865.R, DataName='M10_26-29_865_basetemp_8T_sensorsdisconnected_1nA')
srframe.volt_p1(0)
# Out:
# Started at 2019-11-21 15:54:53
# DataSet:
#    location = 'data/2019-11-21/#007_M10_26-29_865_basetemp_8T_sensorsdisconnected_1nA_15-54-52'
#    <Type>   | <array_id>          | <array.name> | <array.shape>
#    Setpoint | srframe_volt_p1_set | volt_p1      | (321,)
#    Measured | lockin865_X         | X            | (321,)
#    Measured | lockin865_Y         | Y            | (321,)
#    Measured | lockin865_R         | R            | (321,)
# Finished at 2019-11-21 16:02:20

# %%
g26_29_8T_1n = data21.srframe_volt_p1_set[:]
R26_29_8T_1n = data21.lockin865_R[:]/1e-9

# %%
lockin865.amplitude(0.01)
lockin865.time_constant(0.3)
lockin865.filter_slope(12)
srframe.volt_p1(-8)  # try again on 26-29 to see if better wait times, lower current, more sample points take noise away
time.sleep(10)
gvals = np.linspace(-8, 8, 641)
data22, plot22 = npd.single_param_sweep(srframe.volt_p1, gvals, 2.1, lockin865.X, lockin865.Y, lockin865.R, DataName='M10_26-29_865_basetemp_8T_sensorsdisconnected_1nA')
srframe.volt_p1(0)
# Out:
# Started at 2019-11-21 16:23:58
# DataSet:
#    location = 'data/2019-11-21/#008_M10_26-29_865_basetemp_8T_sensorsdisconnected_1nA_16-23-55'
#    <Type>   | <array_id>          | <array.name> | <array.shape>
#    Setpoint | srframe_volt_p1_set | volt_p1      | (641,)
#    Measured | lockin865_X         | X            | (641,)
#    Measured | lockin865_Y         | Y            | (641,)
#    Measured | lockin865_R         | R            | (641,)
# Finished at 2019-11-21 16:47:56

# %%
g26_29_8T_p1n = data22.srframe_volt_p1_set[:]
R26_29_8T_p1n = data22.lockin865_R[:]/0.1e-9

# %%
lockin865.amplitude(0.2)
lockin865.time_constant(0.3)
lockin865.filter_slope(12)
srframe.volt_p1(-8)  # one more try with higher current and longer wait times
time.sleep(10)
gvals = np.linspace(-8, 8, 641)
data23, plot23 = npd.single_param_sweep(srframe.volt_p1, gvals, 2.1, lockin865.X, lockin865.Y, lockin865.R, DataName='M10_26-29_865_basetemp_8T_sensorsdisconnected_1nA')
srframe.volt_p1(0)
# Out:
# Started at 2019-11-21 17:43:53
# DataSet:
#    location = 'data/2019-11-21/#009_M10_26-29_865_basetemp_8T_sensorsdisconnected_1nA_17-43-51'
#    <Type>   | <array_id>          | <array.name> | <array.shape>
#    Setpoint | srframe_volt_p1_set | volt_p1      | (641,)
#    Measured | lockin865_X         | X            | (641,)
#    Measured | lockin865_Y         | Y            | (641,)
#    Measured | lockin865_R         | R            | (641,)
# Finished at 2019-11-21 18:07:50

# %%
srframe.volt_p1(-8)
time.sleep(10)
gvals = np.linspace(-8, 8, 321)
data24, plot24 = npd.single_param_sweep(srframe.volt_p1, gvals, 1, lockin865.X, lockin865.Y, lockin830.X, lockin830.Y, DataName='M10_26-29_830_29_2_865_basetemp_8T_sensorsdisconnected_2nA_repeat')
srframe.volt_p1(0)

g26_29_8T_2 = data24.srframe_volt_p1_set[:]
R26_29_8T_2 = data24.lockin830_X[:]/2e-9
plt.figure(figsize=(8,5))
plt.plot(g26_29_8T_2, (R26_29_8T_2),label='26-29_8T_2')
# Out:
# Started at 2019-11-22 17:37:44
# DataSet:
#    location = 'data/2019-11-22/#001_M10_26-29_830_29_2_865_basetemp_8T_sensorsdisconnected_2nA_repeat_17-37-43'
#    <Type>   | <array_id>          | <array.name> | <array.shape>
#    Setpoint | srframe_volt_p1_set | volt_p1      | (321,)
#    Measured | lockin865_X         | X            | (321,)
#    Measured | lockin865_Y         | Y            | (321,)
#    Measured | lockin830_X         | X            | (321,)
#    Measured | lockin830_Y         | Y            | (321,)
# Finished at 2019-11-22 17:44:05
# <img src="data:image/png;base64,..." width="800">

# %%
srframe.volt_p1(-8)
time.sleep(10)
gvals = np.linspace(-8, 8, 321)
data25, plot25 = npd.single_param_sweep(srframe.volt_p1, gvals, 1, lockin865.X, lockin865.Y, lockin830.X, lockin830.Y, DataName='M10_26-29_830_29_2_865_basetemp_8T_sensorsdisconnected_2nA_repeat_17Hz')
srframe.volt_p1(0)
# Out:
# Started at 2019-11-22 17:50:57
# DataSet:
#    location = 'data/2019-11-22/#002_M10_26-29_830_29_2_865_basetemp_8T_sensorsdisconnected_2nA_repeat_17Hz_17-50-55'
#    <Type>   | <array_id>          | <array.name> | <array.shape>
#    Setpoint | srframe_volt_p1_set | volt_p1      | (321,)
#    Measured | lockin865_X         | X            | (321,)
#    Measured | lockin865_Y         | Y            | (321,)
#    Measured | lockin830_X         | X            | (321,)
#    Measured | lockin830_Y         | Y            | (321,)
# Finished at 2019-11-22 17:57:17

# %%
g26_29_8T_3 = data25.srframe_volt_p1_set[:]
R26_29_8T_3 = data25.lockin830_X[:]/2e-9
plt.figure(figsize=(8,5))
plt.plot(g26_29_8T_2, (R26_29_8T_2),label='26-29_8T_23Hz')
plt.plot(g26_29_8T_3, (R26_29_8T_3),label='26-29_8T_17Hz')
plt.legend()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
gvals = np.linspace(-10, 10, 2001)
bvals = np.linspace(8, 0, 81)
data26, plot26 = npd.twod_param_sweep(triton.field_set_stable, bvals, srframe.volt_p1, gvals, lockin865.X, lockin865.Y, lockin865.R, lockin830.X, lockin830.Y, lockin830.R, SetDelay1=10, SetDelay2=1, DataName='M10_29_2_865and29_26_830_8Tto0T_2nA_13.33Hz')
srframe.volt_p5(0)
srframe.volt_p1(0)
# Out:
# Started at 2019-11-22 18:07:55
# Please wait 10.0 seconds for the field sweep, plus the time required for operating the switch...
# Please wait 49.995999999999995 seconds for the field sweep, plus the time required for operating the switch...
# Please wait 50.001999999999995 seconds for the field sweep, plus the time required for operating the switch...
# Please wait 50.001999999999995 seconds for the field sweep, plus the time required for operating the switch...
# Please wait 50.014 seconds for the field sweep, plus the time required for operating the switch...
# Please wait 50.001999999999995 seconds for the field sweep, plus the time required for operating the switch...
# Please wait 50.001999999999995 seconds for the field sweep, plus the time required for operating the switch...
# Please wait 49.995999999999995 seconds for the field sweep, plus the time required for operating the switch...
# ...

# %% [markdown]
# # Temperature sweeps

# %% [markdown]
# Notes on the temp sweeps from last time:
#
# Use 10 mA range until 1K. Use 31.6 mA range until 1.4. Then 100 mA till 2K. Keep it there for 2-10K, but you must first turn off the turbo, turn V4 on, V9 off, turn the cernox on, RuOx off, and change the pid control channel to the cernox (channel 5).
#
# Last time, it took 5 hrs to get to 1K (401 gate points, 50 mK increments from 50 mK to 1K (20 steps), 2s wait time between gate points, 180s between temp points). Then it was about 18 minutes per temperature point up to 10K (15 hours for 52 and then 5 hours for 15). There's probably no need to go above 4-5K at 0.1K steps.

# %% [markdown]
# Measure 22-20 (M12 with good SC, good fan diagrams) on the lockin865. Measure 26-25 (M10 with good fan diagrams, good correlated insulating states) with lockin830. Use gate range -10 to 10V 401 data points.

# %% [markdown]
# First measure with all sensors unplugged for the best measurement.

# %% [markdown]
# Starting with 1 nA

# %%
gvals = np.linspace(-10, 10, 401) # 1 nA (100 mV on 100 MOhm resistor)
data27_0, plot27_0 = npd.single_param_sweep(srframe.volt_p1, gvals, 1.3, lockin865.X, lockin865.Y, lockin865.R, lockin830.X, lockin830.Y, lockin830.R, DataName='baseTempgatesweep_M12_20-22_lockin865_M10_26-25_lockin830', YParam=[lockin865.X, lockin865.R, lockin830.X, lockin830.R])
# Out:
# Started at 2019-11-25 17:40:33
# DataSet:
#    location = 'data/2019-11-25/#001_baseTempgatesweep_M12_20-22_lockin865_M10_26-25_lockin830_17-40-32'
#    <Type>   | <array_id>          | <array.name> | <array.shape>
#    Setpoint | srframe_volt_p1_set | volt_p1      | (401,)
#    Measured | lockin865_X         | X            | (401,)
#    Measured | lockin865_Y         | Y            | (401,)
#    Measured | lockin865_R         | R            | (401,)
#    Measured | lockin830_X         | X            | (401,)
#    Measured | lockin830_Y         | Y            | (401,)
#    Measured | lockin830_R         | R            | (401,)
# Finished at 2019-11-25 17:50:59

# %%
plt.figure(figsize=(8, 5))
plt.semilogy(gvals, data27_0.lockin865_R[:]/1e-9, label='M12 20-22')
plt.semilogy(gvals, data27_0.lockin830_R[:]/1e-9, label='M10 26-25')
plt.legend()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %% [markdown]
# Try 29-2 on M10 instead of 26-25 and use 0.2nA instead of 1 nA (to get the highest possible SC pocket and insulating peaks)

# %%
gvals = np.linspace(-10, 10, 401) # 0.2 nA (20 mV on 100 MOhm resistor)
data27_1, plot27_1 = npd.single_param_sweep(srframe.volt_p1, gvals, 1.3, lockin865.X, lockin865.Y, lockin865.R, lockin830.X, lockin830.Y, lockin830.R, DataName='baseTempgatesweep_M12_20-22_lockin865_M10_29-2_lockin830', YParam=[lockin865.X, lockin865.R, lockin830.X, lockin830.R])
# Out:
# Started at 2019-11-25 17:55:57
# DataSet:
#    location = 'data/2019-11-25/#002_baseTempgatesweep_M12_20-22_lockin865_M10_29-2_lockin830_17-55-55'
#    <Type>   | <array_id>          | <array.name> | <array.shape>
#    Setpoint | srframe_volt_p1_set | volt_p1      | (401,)
#    Measured | lockin865_X         | X            | (401,)
#    Measured | lockin865_Y         | Y            | (401,)
#    Measured | lockin865_R         | R            | (401,)
#    Measured | lockin830_X         | X            | (401,)
#    Measured | lockin830_Y         | Y            | (401,)
#    Measured | lockin830_R         | R            | (401,)
# Finished at 2019-11-25 18:06:42

# %%
plt.figure(figsize=(8, 5))
plt.semilogy(gvals, data27_1.lockin865_R[:]/0.2e-9, label='M12 20-22')
plt.semilogy(gvals, data27_1.lockin830_R[:]/0.2e-9, label='M10 29-2')
plt.legend()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
lockin865.amplitude(0.02) # use 0.2 nA for everything
lockin830.amplitude(0.02)

# %%
triton.pid_setpoint(0.05)
triton.pid_mode(1)

# %%
triton.pid_range(10)

# %%
Tvals = np.linspace(0.05, 1, 20)
gvals = np.linspace(-10, 10, 401)  # just ignore the temperature measurements here. We can't read temperature while we're in pid mode
data27, plot27 = npd.twod_param_sweep(triton.pid_setpoint, Tvals, srframe.volt_p1, gvals, lockin865.X, lockin865.Y, lockin865.R, lockin830.X, lockin830.Y, lockin830.R, triton.MC_temp, SetDelay1=180, SetDelay2=1.3, Param2_SetBetween=0, DataName='2d_gate_Tempsweep_base-1K_M12_20-22_lockin865_M10_29-2_lockin830', ZParam=[lockin865.X, lockin865.R, lockin830.X, lockin830.R, triton.MC_temp])
# Out:
# Started at 2019-11-25 18:12:35
# DataSet:
#    location = 'data/2019-11-25/#003_2d_gate_Tempsweep_base-1K_M12_20-22_lockin865_M10_29-2_lockin830_18-12-32'
#    <Type>   | <array_id>              | <array.name> | <array.shape>
#    Setpoint | triton_pid_setpoint_set | pid_setpoint | (20,)
#    Setpoint | srframe_volt_p1_set     | volt_p1      | (20, 401)
#    Measured | lockin865_X             | X            | (20, 401)
#    Measured | lockin865_Y             | Y            | (20, 401)
#    Measured | lockin865_R             | R            | (20, 401)
#    Measured | lockin830_X             | X            | (20, 401)
#    Measured | lockin830_Y             | Y            | (20, 401)
#    Measured | lockin830_R             | R            | (20, 401)
#    Measured | triton_MC_temp          | MC_temp      | (20, 401)
# Finished at 2019-11-25 22:46:50

# %%
triton.pid_range(31.6)
time.sleep(3)

# %%
Tvals = np.linspace(1.1, 1.4, 4)
data28, plot28 = npd.twod_param_sweep(triton.pid_setpoint, Tvals, srframe.volt_p1, gvals, lockin865.X, lockin865.Y, lockin865.R, lockin830.X, lockin830.Y, lockin830.R, SetDelay1=180, SetDelay2=1.3, Param2_SetBetween=0, DataName='2d_gate_Tempsweep_1.1-1.4K_M12_20-22_lockin865_M10_29-2_lockin830', ZParam=[lockin865.X, lockin865.R, lockin830.X, lockin830.R])
# Out:
# Started at 2019-11-25 22:46:56
# DataSet:
#    location = 'data/2019-11-25/#004_2d_gate_Tempsweep_1.1-1.4K_M12_20-22_lockin865_M10_29-2_lockin830_22-46-54'
#    <Type>   | <array_id>              | <array.name> | <array.shape>
#    Setpoint | triton_pid_setpoint_set | pid_setpoint | (4,)
#    Setpoint | srframe_volt_p1_set     | volt_p1      | (4, 401)
#    Measured | lockin865_X             | X            | (4, 401)
#    Measured | lockin865_Y             | Y            | (4, 401)
#    Measured | lockin865_R             | R            | (4, 401)
#    Measured | lockin830_X             | X            | (4, 401)
#    Measured | lockin830_Y             | Y            | (4, 401)
#    Measured | lockin830_R             | R            | (4, 401)
# Finished at 2019-11-25 23:39:45

# %%
triton.pid_range(100)
time.sleep(3)

# %%
Tvals = np.linspace(1.5, 2, 6)  #29-2 instead of 26-25
data29, plot29 = npd.twod_param_sweep(triton.pid_setpoint, Tvals, srframe.volt_p1, gvals, lockin865.X, lockin865.Y, lockin865.R, lockin830.X, lockin830.Y, lockin830.R, SetDelay1=180, SetDelay2=1.3, Param2_SetBetween=0, DataName='2d_gate_Tempsweep_1.5-2K_M12_20-22_lockin865_M10_26-25_lockin830', ZParam=[lockin865.X, lockin865.R, lockin830.X, lockin830.R])
# Out:
# Started at 2019-11-25 23:39:52
# DataSet:
#    location = 'data/2019-11-25/#005_2d_gate_Tempsweep_1.5-2K_M12_20-22_lockin865_M10_26-25_lockin830_23-39-49'
#    <Type>   | <array_id>              | <array.name> | <array.shape>
#    Setpoint | triton_pid_setpoint_set | pid_setpoint | (6,)
#    Setpoint | srframe_volt_p1_set     | volt_p1      | (6, 401)
#    Measured | lockin865_X             | X            | (6, 401)
#    Measured | lockin865_Y             | Y            | (6, 401)
#    Measured | lockin865_R             | R            | (6, 401)
#    Measured | lockin830_X             | X            | (6, 401)
#    Measured | lockin830_Y             | Y            | (6, 401)
#    Measured | lockin830_R             | R            | (6, 401)
# Finished at 2019-11-26 00:45:50
# Keyboard Interrupt

# %%
srframe.volt_p1(0)

# %%
triton.pid_setpoint(2)

# %%
triton.pid_mode(0)

# %% [markdown]
# Then turn the settings to the high-temp mode. (cernox on, RuOx off, turbo off, V4 on, V9 off). Switch off the pid mode once the turbo is off. Change to cernox.

# %%
# switch the pid mode on using the computer again
triton.pid_mode(1)
triton.pid_setpoint(2)
triton.pid_range(31.6)

# %%
triton.pid_range(100)

# %%
Tvals = np.linspace(2.0, 5, 31)
data30, plot30 = npd.twod_param_sweep(triton.pid_setpoint, Tvals, srframe.volt_p1, gvals, lockin865.X, lockin865.Y, lockin865.R, lockin830.X, lockin830.Y, lockin830.R, SetDelay1=180, SetDelay2=1.3, Param2_SetBetween=0, DataName='2d_gate_Tempsweep_2-5K_M12_20-22_lockin865_M10_29-2_lockin830', ZParam=[lockin865.X, lockin865.R, lockin830.X, lockin830.R])
# Out:
# Started at 2019-11-26 00:59:37
# DataSet:
#    location = 'data/2019-11-26/#001_2d_gate_Tempsweep_2-5K_M12_20-22_lockin865_M10_29-2_lockin830_00-59-35'
#    <Type>   | <array_id>              | <array.name> | <array.shape>
#    Setpoint | triton_pid_setpoint_set | pid_setpoint | (31,)
#    Setpoint | srframe_volt_p1_set     | volt_p1      | (31, 401)
#    Measured | lockin865_X             | X            | (31, 401)
#    Measured | lockin865_Y             | Y            | (31, 401)
#    Measured | lockin865_R             | R            | (31, 401)
#    Measured | lockin830_X             | X            | (31, 401)
#    Measured | lockin830_Y             | Y            | (31, 401)
#    Measured | lockin830_R             | R            | (31, 401)
# Finished at 2019-11-26 07:49:35

# %%
# optional less-resolved sweep to 10K
Tvals = np.linspace(5.2, 10, 25)
data31, plot31 = npd.twod_param_sweep(triton.pid_setpoint, Tvals, srframe.volt_p1, gvals, lockin865.X, lockin865.Y, lockin865.R, lockin830.X, lockin830.Y, lockin830.R, SetDelay1=180, SetDelay2=1.3, Param2_SetBetween=0, DataName='2d_gate_Tempsweep_5-10K_M12_20-22_lockin865_M10_29-2_lockin830', ZParam=[lockin865.X, lockin865.R, lockin830.X, lockin830.R])
# Out:
# Started at 2019-11-26 07:49:38
# DataSet:
#    location = 'data/2019-11-26/#002_2d_gate_Tempsweep_5-10K_M12_20-22_lockin865_M10_29-2_lockin830_07-49-36'
#    <Type>   | <array_id>              | <array.name> | <array.shape>
#    Setpoint | triton_pid_setpoint_set | pid_setpoint | (25,)
#    Setpoint | srframe_volt_p1_set     | volt_p1      | (25, 401)
#    Measured | lockin865_X             | X            | (25, 401)
#    Measured | lockin865_Y             | Y            | (25, 401)
#    Measured | lockin865_R             | R            | (25, 401)
#    Measured | lockin830_X             | X            | (25, 401)
#    Measured | lockin830_Y             | Y            | (25, 401)
#    Measured | lockin830_R             | R            | (25, 401)
# Finished at 2019-11-26 13:20:14

# %% [markdown]
# # Two-point resistances

# %% [markdown]
# All at 1.5K
#
# First 22-20(M12) on lockin865 and 29-2(M10) on lockin830. Both 0.5nA

# %%
gvals = np.linspace(-14, 14, 281)

# %%
srframe.volt_p1(-14)

# %%
srframe.volt_p1(-14)
time.sleep(9)
data32, plot32 = npd.single_param_sweep(srframe.volt_p1, gvals, 1.3, lockin865.X, lockin865.Y, lockin865.R, lockin830.X, lockin830.Y, lockin830.R, DataName='1p3K_2contact_0p5nA_22-20_865and29-2_830', YParam=[lockin865.R, lockin830.R])
srframe.volt_p1(0)
# Out:
# Started at 2019-11-26 15:08:44
# DataSet:
#    location = 'data/2019-11-26/#006_1p3K_2contact_0p5nA_22-20_865and29-2_830_15-08-43'
#    <Type>   | <array_id>          | <array.name> | <array.shape>
#    Setpoint | srframe_volt_p1_set | volt_p1      | (281,)
#    Measured | lockin865_X         | X            | (281,)
#    Measured | lockin865_Y         | Y            | (281,)
#    Measured | lockin865_R         | R            | (281,)
#    Measured | lockin830_X         | X            | (281,)
#    Measured | lockin830_Y         | Y            | (281,)
#    Measured | lockin830_R         | R            | (281,)
# Finished at 2019-11-26 15:16:21

# %%
srframe.volt_p1(0)

# %%
srframe.volt_p1(-14)
time.sleep(9)
data33, plot33 = npd.single_param_sweep(srframe.volt_p1, gvals, 1.3, lockin865.X, lockin865.Y, lockin865.R, lockin830.X, lockin830.Y, lockin830.R, DataName='1p3K_2contact_0p5nA_12-13_865and26-25_830', YParam=[lockin865.R, lockin830.R])
srframe.volt_p1(0)
# Out:
# Started at 2019-11-26 15:19:58
# DataSet:
#    location = 'data/2019-11-26/#007_1p3K_2contact_0p5nA_12-13_865and26-25_830_15-19-57'
#    <Type>   | <array_id>          | <array.name> | <array.shape>
#    Setpoint | srframe_volt_p1_set | volt_p1      | (281,)
#    Measured | lockin865_X         | X            | (281,)
#    Measured | lockin865_Y         | Y            | (281,)
#    Measured | lockin865_R         | R            | (281,)
#    Measured | lockin830_X         | X            | (281,)
#    Measured | lockin830_Y         | Y            | (281,)
#    Measured | lockin830_R         | R            | (281,)
# Finished at 2019-11-26 15:27:35

# %%
srframe.volt_p1(-14)  # I think I messed up 12-22 by not shorting 22 here. Retook 12-22 two measurements down.
time.sleep(9)
data34, plot34 = npd.single_param_sweep(srframe.volt_p1, gvals, 1.3, lockin865.X, lockin865.Y, lockin865.R, lockin830.X, lockin830.Y, lockin830.R, DataName='1p3K_2contact_0p5nA_12-22_865and26-29_830', YParam=[lockin865.R, lockin830.R])
srframe.volt_p1(0)
# Out:
# Started at 2019-11-26 15:30:17
# DataSet:
#    location = 'data/2019-11-26/#008_1p3K_2contact_0p5nA_12-22_865and26-29_830_15-30-16'
#    <Type>   | <array_id>          | <array.name> | <array.shape>
#    Setpoint | srframe_volt_p1_set | volt_p1      | (281,)
#    Measured | lockin865_X         | X            | (281,)
#    Measured | lockin865_Y         | Y            | (281,)
#    Measured | lockin865_R         | R            | (281,)
#    Measured | lockin830_X         | X            | (281,)
#    Measured | lockin830_Y         | Y            | (281,)
#    Measured | lockin830_R         | R            | (281,)
# Finished at 2019-11-26 15:37:54

# %%
srframe.volt_p1(-14)
time.sleep(9)
data35, plot35 = npd.single_param_sweep(srframe.volt_p1, gvals, 1.3, lockin865.X, lockin865.Y, lockin865.R, lockin830.X, lockin830.Y, lockin830.R, DataName='1p3K_2contact_0p5nA_13-20_865and25-2_830', YParam=[lockin865.R, lockin830.R])
srframe.volt_p1(0)
# Out:
# Started at 2019-11-26 15:41:52
# DataSet:
#    location = 'data/2019-11-26/#009_1p3K_2contact_0p5nA_13-20_865and25-2_830_15-41-51'
#    <Type>   | <array_id>          | <array.name> | <array.shape>
#    Setpoint | srframe_volt_p1_set | volt_p1      | (281,)
#    Measured | lockin865_X         | X            | (281,)
#    Measured | lockin865_Y         | Y            | (281,)
#    Measured | lockin865_R         | R            | (281,)
#    Measured | lockin830_X         | X            | (281,)
#    Measured | lockin830_Y         | Y            | (281,)
#    Measured | lockin830_R         | R            | (281,)
# Finished at 2019-11-26 15:49:29

# %%
srframe.volt_p1(-14)
time.sleep(9)
data36, plot36 = npd.single_param_sweep(srframe.volt_p1, gvals, 1.3, lockin865.X, lockin865.Y, lockin865.R, lockin830.X, lockin830.Y, lockin830.R, DataName='1p3K_2contact_0p5nA_12-22_865and28-29_830', YParam=[lockin865.R, lockin830.R])
srframe.volt_p1(0)
# Out:
# Started at 2019-11-26 15:54:47
# DataSet:
#    location = 'data/2019-11-26/#010_1p3K_2contact_0p5nA_12-22_865and28-29_830_15-54-46'
#    <Type>   | <array_id>          | <array.name> | <array.shape>
#    Setpoint | srframe_volt_p1_set | volt_p1      | (281,)
#    Measured | lockin865_X         | X            | (281,)
#    Measured | lockin865_Y         | Y            | (281,)
#    Measured | lockin865_R         | R            | (281,)
#    Measured | lockin830_X         | X            | (281,)
#    Measured | lockin830_Y         | Y            | (281,)
#    Measured | lockin830_R         | R            | (281,)
# Finished at 2019-11-26 16:02:24

# %%
srframe.volt_p1(-14)
time.sleep(9)
data37, plot37 = npd.single_param_sweep(srframe.volt_p1, gvals, 1.3, lockin865.X, lockin865.Y, lockin865.R, lockin830.X, lockin830.Y, lockin830.R, DataName='1p3K_2contact_0p5nA_19-20_865and28-26_830', YParam=[lockin865.R, lockin830.R])
srframe.volt_p1(0)
# Out:
# Started at 2019-11-26 16:08:30
# DataSet:
#    location = 'data/2019-11-26/#012_1p3K_2contact_0p5nA_19-20_865and28-26_830_16-08-29'
#    <Type>   | <array_id>          | <array.name> | <array.shape>
#    Setpoint | srframe_volt_p1_set | volt_p1      | (281,)
#    Measured | lockin865_X         | X            | (281,)
#    Measured | lockin865_Y         | Y            | (281,)
#    Measured | lockin865_R         | R            | (281,)
#    Measured | lockin830_X         | X            | (281,)
#    Measured | lockin830_Y         | Y            | (281,)
#    Measured | lockin830_R         | R            | (281,)
# Finished at 2019-11-26 16:16:07

# %%
srframe.volt_p1(-14)
time.sleep(9)
data37, plot37 = npd.single_param_sweep(srframe.volt_p1, gvals, 1.3, lockin865.X, lockin865.Y, lockin865.R, lockin830.X, lockin830.Y, lockin830.R, DataName='1p3K_2contact_0p5nA_23-22_865and2-3_830', YParam=[lockin865.R, lockin830.R])
srframe.volt_p1(0)
# Out:
# Started at 2019-11-26 16:21:37
# DataSet:
#    location = 'data/2019-11-26/#013_1p3K_2contact_0p5nA_23-22_865and2-3_830_16-21-36'
#    <Type>   | <array_id>          | <array.name> | <array.shape>
#    Setpoint | srframe_volt_p1_set | volt_p1      | (281,)
#    Measured | lockin865_X         | X            | (281,)
#    Measured | lockin865_Y         | Y            | (281,)
#    Measured | lockin865_R         | R            | (281,)
#    Measured | lockin830_X         | X            | (281,)
#    Measured | lockin830_Y         | Y            | (281,)
#    Measured | lockin830_R         | R            | (281,)
# Finished at 2019-11-26 16:29:28

# %%
srframe.volt_p1(-14)  # contact 11 doesn't work
time.sleep(9)
data39, plot39 = npd.single_param_sweep(srframe.volt_p1, gvals, 1.3, lockin865.X, lockin865.Y, lockin865.R, lockin830.X, lockin830.Y, lockin830.R, DataName='1p3K_2contact_0p5nA_11-12_865and25-4_830', YParam=[lockin865.R, lockin830.R])
srframe.volt_p1(0)
# Out:
# Started at 2019-11-26 16:33:06
# DataSet:
#    location = 'data/2019-11-26/#014_1p3K_2contact_0p5nA_11-12_865and25-4_830_16-33-06'
#    <Type>   | <array_id>          | <array.name> | <array.shape>
#    Setpoint | srframe_volt_p1_set | volt_p1      | (281,)
#    Measured | lockin865_X         | X            | (281,)
#    Measured | lockin865_Y         | Y            | (281,)
#    Measured | lockin865_R         | R            | (281,)
#    Measured | lockin830_X         | X            | (281,)
#    Measured | lockin830_Y         | Y            | (281,)
#    Measured | lockin830_R         | R            | (281,)
# Finished at 2019-11-26 16:40:44

# %%
srframe.volt_p1(-14)
time.sleep(11)
data40, plot40 = npd.single_param_sweep(srframe.volt_p1, gvals, 1.3, lockin865.X, lockin865.Y, lockin865.R, lockin830.X, lockin830.Y, lockin830.R, DataName='1p3K_2contact_0p5nA_24-23_865and3-8_830', YParam=[lockin865.R, lockin830.R])
srframe.volt_p1(0)
# Out:
# Started at 2019-11-26 16:43:39
# DataSet:
#    location = 'data/2019-11-26/#015_1p3K_2contact_0p5nA_24-23_865and3-8_830_16-43-38'
#    <Type>   | <array_id>          | <array.name> | <array.shape>
#    Setpoint | srframe_volt_p1_set | volt_p1      | (281,)
#    Measured | lockin865_X         | X            | (281,)
#    Measured | lockin865_Y         | Y            | (281,)
#    Measured | lockin865_R         | R            | (281,)
#    Measured | lockin830_X         | X            | (281,)
#    Measured | lockin830_Y         | Y            | (281,)
#    Measured | lockin830_R         | R            | (281,)
# Finished at 2019-11-26 16:51:16

# %%
plt.figure(figsize=(8, 5))
#plt.semilogy(gvals, 1/(data32.lockin830_R[:]/0.5e-9), label='M10 29-2')
plt.semilogy(gvals, 1/(data33.lockin830_R[:]/0.5e-9), label='M10 26-25')
plt.semilogy(gvals, 1/(data34.lockin830_R[:]/0.5e-9), label='M10 26-29')
#plt.semilogy(gvals, 1 /(data35.lockin830_R[:]/0.5e-9), label='M10 25-2')
plt.semilogy(gvals, 1/(data36.lockin830_R[:]/0.5e-9), label='M10 28-29')
#plt.semilogy(gvals, 1/(data37.lockin830_R[:]/0.5e-9), label='M10 2-3')
plt.semilogy(gvals, 1/(data39.lockin830_R[:]/0.5e-9), label='M10 25-4')
#plt.semilogy(gvals, 1/(data40.lockin830_R[:]/0.5e-9), label='M10 3-8')
plt.legend()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
triton.close()
srframe.close()
lockin865.close()
lockin830.close()
