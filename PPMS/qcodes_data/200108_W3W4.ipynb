# %%
import qcodes as qc
import qcodes.instrument_drivers.nplab_drivers as npd
import numpy as np
import time
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm, SymLogNorm, DivergingNorm

# %%
npd.ppms_init('lockin1', 'lockin2', 'srdc')
# Out:
# Note this uses mT units for getting and setting fields with field() and field_set_stable(). Just divide Oe by 10 to get mT
# Connected to: Stanford_Research_Systems SR830 (serial:s/n22100, firmware:ver1.01) in 0.15s
# Connected to: Stanford_Research_Systems SR830 (serial:s/n35235, firmware:ver1.07) in 0.06s
# Connected to: Stanford_Research_Systems DC205 (serial:s/n20500044, firmware:ver1.80) in 0.03s

# %%
station = qc.Station(ppms, lockin1, lockin2, srdc)

# %%
srdc.volt.step = 0.05
srdc.volt.inter_delay = 0.1

# %%
srdc.output(1)

# %%
srdc.range(1) #+/- 10V range

# %%
srdc.range(2)

# %%
srdc.volt(0)

# %%
srdc.volt(0)

# %%
srdc.volt(-5)
time.sleep(7)
gvals = np.linspace(-5, 5, 101)
data1, plot1 = npd.single_param_sweep(srdc.volt, gvals, 2, lockin2.X, lockin2.Y, DataName='W4_11-12_gsweep_300K_10nA')
# Out:
# Started at 2020-01-08 17:34:51
# DataSet:
#    location = 'data/2020-01-08/#001_W4_11-12_gsweep_300K_10nA_17-34-47'
#    <Type>   | <array_id>    | <array.name> | <array.shape>
#    Setpoint | srdc_volt_set | volt         | (101,)
#    Measured | lockin2_X     | X            | (101,)
#    Measured | lockin2_Y     | Y            | (101,)
# Finished at 2020-01-08 17:38:30

# %%
srdc.volt(0)

# %%
ppms.temperature_rate = 5
ppms.temperature(2)

# %%
srdc.volt(-5)
time.sleep(7)
gvals = np.linspace(-5, 5, 101)
data2, plot2 = npd.single_param_sweep(srdc.volt, gvals, 1, lockin2.X, lockin2.Y, DataName='W4_11-12_gsweep_180Kmaybe_10nA')
# Out:
# Started at 2020-01-08 18:01:14
# DataSet:
#    location = 'data/2020-01-08/#002_W4_11-12_gsweep_180Kmaybe_10nA_18-01-13'
#    <Type>   | <array_id>    | <array.name> | <array.shape>
#    Setpoint | srdc_volt_set | volt         | (101,)
#    Measured | lockin2_X     | X            | (101,)
#    Measured | lockin2_Y     | Y            | (101,)
# Finished at 2020-01-08 18:03:12

# %%
srdc.volt(-10)
time.sleep(7)
gvals = np.linspace(-10, 10, 201)
data3, plot3 = npd.single_param_sweep(srdc.volt, gvals, 1, lockin2.X, lockin2.Y, DataName='W4_11-12_gsweep_150Kmaybe_10nA')
# Out:
# Started at 2020-01-08 18:04:33
# DataSet:
#    location = 'data/2020-01-08/#003_W4_11-12_gsweep_150Kmaybe_10nA_18-04-32'
#    <Type>   | <array_id>    | <array.name> | <array.shape>
#    Setpoint | srdc_volt_set | volt         | (201,)
#    Measured | lockin2_X     | X            | (201,)
#    Measured | lockin2_Y     | Y            | (201,)
# Finished at 2020-01-08 18:08:28

# %%
srdc.volt(-0)

# %%
srdc.volt(-10)
time.sleep(7)
gvals = np.linspace(-10, 10, 201)
data4, plot4 = npd.single_param_sweep(srdc.volt, gvals, 1, lockin2.X, lockin2.Y, DataName='W4_11-12_gsweep_90Kmaybe_10nA')
# Out:
# Started at 2020-01-08 18:11:43
# DataSet:
#    location = 'data/2020-01-08/#004_W4_11-12_gsweep_90Kmaybe_10nA_18-11-42'
#    <Type>   | <array_id>    | <array.name> | <array.shape>
#    Setpoint | srdc_volt_set | volt         | (201,)
#    Measured | lockin2_X     | X            | (201,)
#    Measured | lockin2_Y     | Y            | (201,)
# Finished at 2020-01-08 18:15:38

# %%
plot4[0]

# %%
srdc.volt(0)
time.sleep(7)
gvals = np.linspace(0, 10, 51)
data5, plot5 = npd.single_param_sweep(srdc.volt, gvals, 1, lockin2.X, lockin2.Y, DataName='W4_11-12_gsweep_40Kmaybe_10nA')
# Out:
# Started at 2020-01-08 18:17:42
# DataSet:
#    location = 'data/2020-01-08/#005_W4_11-12_gsweep_40Kmaybe_10nA_18-17-41'
#    <Type>   | <array_id>    | <array.name> | <array.shape>
#    Setpoint | srdc_volt_set | volt         | (51,)
#    Measured | lockin2_X     | X            | (51,)
#    Measured | lockin2_Y     | Y            | (51,)
# Finished at 2020-01-08 18:18:52

# %%
srdc.volt(-10)
time.sleep(7)
gvals = np.linspace(-10, 10, 201)
data6, plot6 = npd.single_param_sweep(srdc.volt, gvals, 1, lockin2.X, lockin2.Y, DataName='W4_11-12_gsweep_4Kmaybe_10nA')
# Out:
# Started at 2020-01-08 18:25:00
# DataSet:
#    location = 'data/2020-01-08/#006_W4_11-12_gsweep_4Kmaybe_10nA_18-24-59'
#    <Type>   | <array_id>    | <array.name> | <array.shape>
#    Setpoint | srdc_volt_set | volt         | (201,)
#    Measured | lockin2_X     | X            | (201,)
#    Measured | lockin2_Y     | Y            | (201,)
# Finished at 2020-01-08 18:28:55

# %%
srdc.volt(0)

# %%
srdc.volt(-10)
time.sleep(7)
gvals = np.linspace(-10, 10, 201)
data7, plot7 = npd.single_param_sweep(srdc.volt, gvals, 1, lockin2.X, lockin2.Y, DataName='W4_10-11_gsweep_2Kmaybe_10nA')
# Out:
# Started at 2020-01-08 18:36:30
# DataSet:
#    location = 'data/2020-01-08/#007_W4_10-11_gsweep_2Kmaybe_10nA_18-36-29'
#    <Type>   | <array_id>    | <array.name> | <array.shape>
#    Setpoint | srdc_volt_set | volt         | (201,)
#    Measured | lockin2_X     | X            | (201,)
#    Measured | lockin2_Y     | Y            | (201,)
# Finished at 2020-01-08 18:40:26

# %%
srdc.volt(-10)
time.sleep(7)
gvals = np.linspace(-10, 10, 201)
data8, plot8 = npd.single_param_sweep(srdc.volt, gvals, 1, lockin2.X, lockin2.Y, DataName='W4_10-9_gsweep_2Kmaybe_10nA')
# Out:
# Started at 2020-01-08 18:43:00
# DataSet:
#    location = 'data/2020-01-08/#008_W4_10-9_gsweep_2Kmaybe_10nA_18-42-59'
#    <Type>   | <array_id>    | <array.name> | <array.shape>
#    Setpoint | srdc_volt_set | volt         | (201,)
#    Measured | lockin2_X     | X            | (201,)
#    Measured | lockin2_Y     | Y            | (201,)
# Finished at 2020-01-08 18:46:55

# %%
srdc.volt(-10)
time.sleep(7)
gvals = np.linspace(-10, 10, 201)
data9, plot9 = npd.single_param_sweep(srdc.volt, gvals, 1, lockin2.X, lockin2.Y, DataName='W4_8-9_gsweep_2Kmaybe_10nA')
# Out:
# Started at 2020-01-08 18:49:22
# DataSet:
#    location = 'data/2020-01-08/#009_W4_8-9_gsweep_2Kmaybe_10nA_18-49-21'
#    <Type>   | <array_id>    | <array.name> | <array.shape>
#    Setpoint | srdc_volt_set | volt         | (201,)
#    Measured | lockin2_X     | X            | (201,)
#    Measured | lockin2_Y     | Y            | (201,)
# Finished at 2020-01-08 18:53:18

# %%
srdc.volt(-10)
time.sleep(7)
gvals = np.linspace(-10, 10, 201)
data10, plot10 = npd.single_param_sweep(srdc.volt, gvals, 1, lockin2.X, lockin2.Y, DataName='W4_8-7_gsweep_2K_10nA')
# Out:
# Started at 2020-01-08 18:55:52
# DataSet:
#    location = 'data/2020-01-08/#010_W4_8-7_gsweep_2K_10nA_18-55-51'
#    <Type>   | <array_id>    | <array.name> | <array.shape>
#    Setpoint | srdc_volt_set | volt         | (201,)
#    Measured | lockin2_X     | X            | (201,)
#    Measured | lockin2_Y     | Y            | (201,)
# Finished at 2020-01-08 18:59:47

# %%
srdc.volt(-10)
time.sleep(7)
gvals = np.linspace(-10, 10, 201)
data11, plot11 = npd.single_param_sweep(srdc.volt, gvals, 1, lockin1.X, lockin1.Y, lockin2.X, lockin2.Y, DataName='W4_lockin2_8-9_lockin1_11-12gsweep_2Kmaybe_10nA')
# Out:
# Started at 2020-01-08 19:29:45
# DataSet:
#    location = 'data/2020-01-08/#012_W4_lockin2_8-9_lockin1_11-12gsweep_2Kmaybe_10nA_19-29-43'
#    <Type>   | <array_id>    | <array.name> | <array.shape>
#    Setpoint | srdc_volt_set | volt         | (201,)
#    Measured | lockin1_X     | X            | (201,)
#    Measured | lockin1_Y     | Y            | (201,)
#    Measured | lockin2_X     | X            | (201,)
#    Measured | lockin2_Y     | Y            | (201,)
# Finished at 2020-01-08 19:33:54

# %%
gvals = np.linspace(-10, 10, 201)
fieldvals = np.linspace(0, 9000, 181)
data12, plot12 = npd.twod_param_sweep(ppms.field_set_stable, fieldvals, srdc.volt, gvals, lockin1.X, lockin1.Y, lockin2.X, lockin2.Y, SetDelay1=10, SetDelay2=0.7, Param2_SetBetween=-8, DataName='W4_lockin2_8-9_lockin1_11-12_Fan0Tto9T_1p8K_10nA')
srdc.volt(0)
# Out:
# Started at 2020-01-08 19:38:55
# DataSet:
#    location = 'data/2020-01-08/#015_W4_lockin2_8-9_lockin1_11-12_Fan0Tto9T_1p8K_10nA_19-38-52'
#    <Type>   | <array_id>                | <array.name>     | <array.shape>
#    Setpoint | ppms_field_set_stable_set | field_set_stable | (181,)
#    Setpoint | srdc_volt_set             | volt             | (181, 201)
#    Measured | lockin1_X                 | X                | (181, 201)
#    Measured | lockin1_Y                 | Y                | (181, 201)
#    Measured | lockin2_X                 | X                | (181, 201)
#    Measured | lockin2_Y                 | Y                | (181, 201)
# Finished at 2020-01-08 20:33:07
# Keyboard Interrupt

# %%
srdc.volt(0)

# %%
gvals = np.linspace(-5, 5, 201)
fieldvals = np.linspace(0, 9000, 181)
data12, plot12 = npd.twod_param_sweep(ppms.field_set_stable, fieldvals, srdc.volt, gvals, lockin1.X, lockin1.Y, lockin2.X, lockin2.Y, SetDelay1=10, SetDelay2=0.7, Param2_SetBetween=-8, DataName='W4_lockin2_8-9_lockin1_11-12_Fan0Tto9T_1p8K_10nA')
srdc.volt(0)
# Out:
# Started at 2020-01-08 20:35:31
# DataSet:
#    location = 'data/2020-01-08/#016_W4_lockin2_8-9_lockin1_11-12_Fan0Tto9T_1p8K_10nA_20-35-28'
#    <Type>   | <array_id>                | <array.name>     | <array.shape>
#    Setpoint | ppms_field_set_stable_set | field_set_stable | (181,)
#    Setpoint | srdc_volt_set             | volt             | (181, 201)
#    Measured | lockin1_X                 | X                | (181, 201)
#    Measured | lockin1_Y                 | Y                | (181, 201)
#    Measured | lockin2_X                 | X                | (181, 201)
#    Measured | lockin2_Y                 | Y                | (181, 201)
# Finished at 2020-01-09 06:48:29

# %%
srdc.volt(0)

# %%
ppms.field_set_stable(0)

# %%
lockin2.amplitude(0.02)

# %%
#now W3

# %%
srdc.volt(0)

# %%
srdc.volt(5)
time.sleep(7)
gvals = np.linspace(5, -5, 101)
data14, plot14 = npd.single_param_sweep(srdc.volt, gvals, 1, lockin1.X, lockin1.Y, lockin2.X, lockin2.Y, DataName='W3_lockin2_3-14_lockin1_14-13gsweep_230K_10nA')
# Out:
# Started at 2020-01-09 10:27:25
# DataSet:
#    location = 'data/2020-01-09/#002_W3_lockin2_3-14_lockin1_14-13gsweep_230K_10nA_10-27-23'
#    <Type>   | <array_id>    | <array.name> | <array.shape>
#    Setpoint | srdc_volt_set | volt         | (101,)
#    Measured | lockin1_X     | X            | (101,)
#    Measured | lockin1_Y     | Y            | (101,)
#    Measured | lockin2_X     | X            | (101,)
#    Measured | lockin2_Y     | Y            | (101,)
# Finished at 2020-01-09 10:29:30

# %%
srdc.volt(5)
time.sleep(7)
gvals = np.linspace(5, -5, 101)
data13, plot13 = npd.single_param_sweep(srdc.volt, gvals, 1, lockin1.X, lockin1.Y, lockin2.X, lockin2.Y, DataName='W3_lockin2_3-14_lockin1_14-13gsweep_RT_10nA')

# %%
ppms.temperature_rate = 7
ppms.temperature(2)

# %%
srdc.volt(5)
time.sleep(7)
gvals = np.linspace(5, -5, 101)
data14, plot14 = npd.single_param_sweep(srdc.volt, gvals, 1, lockin1.X, lockin1.Y, lockin2.X, lockin2.Y, DataName='W3_lockin2_3-14_lockin1_14-13gsweep_160K_10nA')
# Out:
# Started at 2020-01-09 10:37:03
# DataSet:
#    location = 'data/2020-01-09/#003_W3_lockin2_3-14_lockin1_14-13gsweep_160K_10nA_10-37-01'
#    <Type>   | <array_id>    | <array.name> | <array.shape>
#    Setpoint | srdc_volt_set | volt         | (101,)
#    Measured | lockin1_X     | X            | (101,)
#    Measured | lockin1_Y     | Y            | (101,)
#    Measured | lockin2_X     | X            | (101,)
#    Measured | lockin2_Y     | Y            | (101,)
# Finished at 2020-01-09 10:39:08

# %%
srdc.volt(5)
time.sleep(7)
gvals = np.linspace(5, -5, 101)
data15, plot15 = npd.single_param_sweep(srdc.volt, gvals, 1, lockin1.X, lockin1.Y, lockin2.X, lockin2.Y, DataName='W3_lockin2_3-14_lockin1_14-13gsweep_100K_10nA')
# Out:
# Started at 2020-01-09 10:46:40
# DataSet:
#    location = 'data/2020-01-09/#004_W3_lockin2_3-14_lockin1_14-13gsweep_100K_10nA_10-46-38'
#    <Type>   | <array_id>    | <array.name> | <array.shape>
#    Setpoint | srdc_volt_set | volt         | (101,)
#    Measured | lockin1_X     | X            | (101,)
#    Measured | lockin1_Y     | Y            | (101,)
#    Measured | lockin2_X     | X            | (101,)
#    Measured | lockin2_Y     | Y            | (101,)
# Finished at 2020-01-09 10:48:45

# %%
srdc.volt(5)
time.sleep(7)
gvals = np.linspace(5, -5, 101)
data16, plot16 = npd.single_param_sweep(srdc.volt, gvals, 1, lockin1.X, lockin1.Y, lockin2.X, lockin2.Y, DataName='W3_lockin2_3-14_lockin1_14-13gsweep_50K_10nA')
# Out:
# Started at 2020-01-09 10:53:05
# DataSet:
#    location = 'data/2020-01-09/#005_W3_lockin2_3-14_lockin1_14-13gsweep_50K_10nA_10-53-03'
#    <Type>   | <array_id>    | <array.name> | <array.shape>
#    Setpoint | srdc_volt_set | volt         | (101,)
#    Measured | lockin1_X     | X            | (101,)
#    Measured | lockin1_Y     | Y            | (101,)
#    Measured | lockin2_X     | X            | (101,)
#    Measured | lockin2_Y     | Y            | (101,)
# Finished at 2020-01-09 10:55:10

# %%
srdc.volt(5)
time.sleep(7)
gvals = np.linspace(5, -5, 101)
data17, plot17 = npd.single_param_sweep(srdc.volt, gvals, 1, lockin1.X, lockin1.Y, lockin2.X, lockin2.Y, DataName='W3_lockin2_3-14_lockin1_14-13gsweep_5K_10nA')
# Out:
# Started at 2020-01-09 11:01:29
# DataSet:
#    location = 'data/2020-01-09/#006_W3_lockin2_3-14_lockin1_14-13gsweep_5K_10nA_11-01-27'
#    <Type>   | <array_id>    | <array.name> | <array.shape>
#    Setpoint | srdc_volt_set | volt         | (101,)
#    Measured | lockin1_X     | X            | (101,)
#    Measured | lockin1_Y     | Y            | (101,)
#    Measured | lockin2_X     | X            | (101,)
#    Measured | lockin2_Y     | Y            | (101,)
# Finished at 2020-01-09 11:03:34

# %%
srdc.volt(0)

# %%
srdc.volt(-7)
time.sleep(7)
gvals = np.linspace(-7, 7, 141)
data18, plot18 = npd.single_param_sweep(srdc.volt, gvals, 1, lockin1.X, lockin1.Y, lockin2.X, lockin2.Y, DataName='W3_lockin2_3-14_lockin1_14-13gsweep_3K_10nA')
# Out:
# Started at 2020-01-09 11:04:46
# DataSet:
#    location = 'data/2020-01-09/#007_W3_lockin2_3-14_lockin1_14-13gsweep_3K_10nA_11-04-44'
#    <Type>   | <array_id>    | <array.name> | <array.shape>
#    Setpoint | srdc_volt_set | volt         | (141,)
#    Measured | lockin1_X     | X            | (141,)
#    Measured | lockin1_Y     | Y            | (141,)
#    Measured | lockin2_X     | X            | (141,)
#    Measured | lockin2_Y     | Y            | (141,)
# Finished at 2020-01-09 11:07:41

# %%
lockin2.amplitude(0.2)

# %%
srdc.volt(-7)
time.sleep(7)
gvals = np.linspace(-7, 7, 141)
data19, plot19 = npd.single_param_sweep(srdc.volt, gvals, 1, lockin1.X, lockin1.Y, lockin2.X, lockin2.Y, DataName='W3_lockin2_3-14_lockin1_14-13gsweep_2K_2nA')
# Out:
# Started at 2020-01-09 11:09:42
# DataSet:
#    location = 'data/2020-01-09/#008_W3_lockin2_3-14_lockin1_14-13gsweep_2K_2nA_11-09-40'
#    <Type>   | <array_id>    | <array.name> | <array.shape>
#    Setpoint | srdc_volt_set | volt         | (141,)
#    Measured | lockin1_X     | X            | (141,)
#    Measured | lockin1_Y     | Y            | (141,)
#    Measured | lockin2_X     | X            | (141,)
#    Measured | lockin2_Y     | Y            | (141,)
# Finished at 2020-01-09 11:12:37

# %%
plt.figure(figsize=(10, 6))
plt.semilogy(data19.srdc_volt_set[:], np.abs(data19.lockin1_X[:])/2e-9, label= '10-9 5nA')
plt.legend()

# %%
lockin2.amplitude(0.5)

# %%
#now check the angle of different pairs

# %%
srdc.volt(-7)
time.sleep(7)
gvals = np.linspace(-7, 7, 141)
data20, plot20 = npd.single_param_sweep(srdc.volt, gvals, 1, lockin2.X, lockin2.Y, DataName='W3_lockin2_3-14_gsweep_1.8K_5nA')
# Out:
# Started at 2020-01-09 13:13:59
# DataSet:
#    location = 'data/2020-01-09/#009_W3_lockin2_3-14_gsweep_1.8K_5nA_13-13-58'
#    <Type>   | <array_id>    | <array.name> | <array.shape>
#    Setpoint | srdc_volt_set | volt         | (141,)
#    Measured | lockin2_X     | X            | (141,)
#    Measured | lockin2_Y     | Y            | (141,)
# Finished at 2020-01-09 13:16:44

# %%
srdc.volt(0)

# %%
srdc.volt(8)
time.sleep(10)
gvals = np.linspace(8, -7, 301)
data20, plot20 = npd.single_param_sweep(srdc.volt, gvals, 2, lockin2.X, lockin2.Y, DataName='W3_lockin2_3-14_gsweep_1.8K_5nA')
# Out:
# Started at 2020-01-09 13:20:30
# DataSet:
#    location = 'data/2020-01-09/#010_W3_lockin2_3-14_gsweep_1.8K_5nA_13-20-29'
#    <Type>   | <array_id>    | <array.name> | <array.shape>
#    Setpoint | srdc_volt_set | volt         | (301,)
#    Measured | lockin2_X     | X            | (301,)
#    Measured | lockin2_Y     | Y            | (301,)
# Finished at 2020-01-09 13:30:53

# %%
srdc.volt(8)
time.sleep(10)
gvals = np.linspace(8, -7, 301)
data21, plot21 = npd.single_param_sweep(srdc.volt, gvals, 2, lockin2.X, lockin2.Y, DataName='W3_lockin2_14-13_gsweep_1.8K_5nA')
# Out:
# Started at 2020-01-09 13:34:15
# DataSet:
#    location = 'data/2020-01-09/#011_W3_lockin2_14-13_gsweep_1.8K_5nA_13-34-14'
#    <Type>   | <array_id>    | <array.name> | <array.shape>
#    Setpoint | srdc_volt_set | volt         | (301,)
#    Measured | lockin2_X     | X            | (301,)
#    Measured | lockin2_Y     | Y            | (301,)
# Finished at 2020-01-09 13:38:05
# Keyboard Interrupt

# %%
srdc.volt(8)
time.sleep(10)
gvals = np.linspace(8, -7, 301)
data22, plot22 = npd.single_param_sweep(srdc.volt, gvals, 2, lockin2.X, lockin2.Y, DataName='W3_lockin2_13-12_gsweep_1.8K_5nA')
# Out:
# Started at 2020-01-09 13:42:03
# DataSet:
#    location = 'data/2020-01-09/#012_W3_lockin2_13-12_gsweep_1.8K_5nA_13-42-01'
#    <Type>   | <array_id>    | <array.name> | <array.shape>
#    Setpoint | srdc_volt_set | volt         | (301,)
#    Measured | lockin2_X     | X            | (301,)
#    Measured | lockin2_Y     | Y            | (301,)
# Finished at 2020-01-09 13:52:25

# %%
srdc.volt(8)
time.sleep(10)
gvals = np.linspace(8, -7, 301)
data23, plot23 = npd.single_param_sweep(srdc.volt, gvals, 2, lockin2.X, lockin2.Y, DataName='W3_lockin2_12-11_gsweep_1.8K_5nA')
# Out:
# Started at 2020-01-09 13:55:15
# DataSet:
#    location = 'data/2020-01-09/#013_W3_lockin2_12-11_gsweep_1.8K_5nA_13-55-14'
#    <Type>   | <array_id>    | <array.name> | <array.shape>
#    Setpoint | srdc_volt_set | volt         | (301,)
#    Measured | lockin2_X     | X            | (301,)
#    Measured | lockin2_Y     | Y            | (301,)
# Finished at 2020-01-09 14:05:38

# %%
srdc.volt(8)
time.sleep(10)
gvals = np.linspace(8, -7, 301)
data24, plot24 = npd.single_param_sweep(srdc.volt, gvals, 2, lockin2.X, lockin2.Y, DataName='W3_lockin2_6-7_gsweep_1.8K_5nA')
# Out:
# Started at 2020-01-09 14:13:01
# DataSet:
#    location = 'data/2020-01-09/#014_W3_lockin2_6-7_gsweep_1.8K_5nA_14-13-00'
#    <Type>   | <array_id>    | <array.name> | <array.shape>
#    Setpoint | srdc_volt_set | volt         | (301,)
#    Measured | lockin2_X     | X            | (301,)
#    Measured | lockin2_Y     | Y            | (301,)
# Finished at 2020-01-09 14:23:24

# %%
lockin2.amplitude(1)

# %%
srdc.volt(8)
time.sleep(10)
gvals = np.linspace(8, -7, 301)
data25, plot25 = npd.single_param_sweep(srdc.volt, gvals, 2, lockin2.X, lockin2.Y, DataName='W3_lockin2_6-7_gsweep_1.8K_10nA')
# Out:
# Started at 2020-01-09 14:26:03
# DataSet:
#    location = 'data/2020-01-09/#015_W3_lockin2_6-7_gsweep_1.8K_10nA_14-26-02'
#    <Type>   | <array_id>    | <array.name> | <array.shape>
#    Setpoint | srdc_volt_set | volt         | (301,)
#    Measured | lockin2_X     | X            | (301,)
#    Measured | lockin2_Y     | Y            | (301,)
# Finished at 2020-01-09 14:36:25

# %%
lockin2.amplitude(0.2)

# %%
srdc.volt(8)
time.sleep(10)
gvals = np.linspace(8, -7, 301)
data26, plot26 = npd.single_param_sweep(srdc.volt, gvals, 2, lockin2.X, lockin2.Y, DataName='W3_lockin2_6-7_gsweep_1.8K_2nA')
# Out:
# Started at 2020-01-09 14:38:09
# DataSet:
#    location = 'data/2020-01-09/#016_W3_lockin2_6-7_gsweep_1.8K_2nA_14-38-08'
#    <Type>   | <array_id>    | <array.name> | <array.shape>
#    Setpoint | srdc_volt_set | volt         | (301,)
#    Measured | lockin2_X     | X            | (301,)
#    Measured | lockin2_Y     | Y            | (301,)
# Finished at 2020-01-09 14:48:32

# %%
lockin2.amplitude(0.5)

# %%
plt.figure(figsize=(10, 6))
plt.semilogy(data20.srdc_volt_set[:], np.abs(data20.lockin2_X[:])/5e-9, label= '3-14 5nA')
plt.semilogy(data22.srdc_volt_set[:], np.abs(data22.lockin2_X[:])/5e-9, label= '13-12 5nA')
plt.semilogy(data23.srdc_volt_set[:], np.abs(data23.lockin2_X[:])/5e-9, label= '12-11 5nA')
plt.semilogy(data24.srdc_volt_set[:], np.abs(data24.lockin2_X[:])/5e-9, label= '6-7 5nA')
plt.legend()

# %%
plt.figure(figsize=(10, 6))
plt.semilogy(data24.srdc_volt_set[:], np.abs(data24.lockin2_X[:])/5e-9, label= '6-7 5nA')
plt.semilogy(data25.srdc_volt_set[:], np.abs(data25.lockin2_X[:])/10e-9, label= '6-7 10nA')
plt.semilogy(data26.srdc_volt_set[:], np.abs(data26.lockin2_X[:])/2e-9, label= '6-7 2nA')
plt.legend()

# %%
#7-8 big Y

# %%
srdc.volt(8)
time.sleep(10)
gvals = np.linspace(8, -7, 301)
data27, plot27 = npd.single_param_sweep(srdc.volt, gvals, 1, lockin1.X, lockin1.Y, lockin2.X, lockin2.Y, DataName='W3_lockin2_12-13_lockin1_11-12_gsweep_1.8K_5nA')
# Out:
# Started at 2020-01-09 15:06:32
# DataSet:
#    location = 'data/2020-01-09/#018_W3_lockin2_12-13_lockin1_11-12_gsweep_1.8K_5nA_15-06-30'
#    <Type>   | <array_id>    | <array.name> | <array.shape>
#    Setpoint | srdc_volt_set | volt         | (301,)
#    Measured | lockin1_X     | X            | (301,)
#    Measured | lockin1_Y     | Y            | (301,)
#    Measured | lockin2_X     | X            | (301,)
#    Measured | lockin2_Y     | Y            | (301,)
# Finished at 2020-01-09 15:12:17

# %%
plot27[0]

# %%
gvals = np.linspace(7, -7, 561)  # cut short to do a temp sweep. actually 5 nA
fieldvals = np.linspace(0, 9000, 181)
data28, plot28 = npd.twod_param_sweep(ppms.field_set_stable, fieldvals, srdc.volt, gvals, lockin1.X, lockin1.Y, lockin2.X, lockin2.Y, SetDelay1=10, SetDelay2=1, Param2_SetBetween=-8, DataName='W3_lockin2_12-13_lockin1_11-12_Fan0Tto9T_1p8K_10nA')
srdc.volt(0)
# Out:
# Started at 2020-01-09 15:20:52
# DataSet:
#    location = 'data/2020-01-09/#019_W3_lockin2_12-13_lockin1_11-12_Fan0Tto9T_1p8K_10nA_15-20-49'
#    <Type>   | <array_id>                | <array.name>     | <array.shape>
#    Setpoint | ppms_field_set_stable_set | field_set_stable | (181,)
#    Setpoint | srdc_volt_set             | volt             | (181, 561)
#    Measured | lockin1_X                 | X                | (181, 561)
#    Measured | lockin1_Y                 | Y                | (181, 561)
#    Measured | lockin2_X                 | X                | (181, 561)
#    Measured | lockin2_Y                 | Y                | (181, 561)
# Finished at 2020-01-09 16:24:42
# Keyboard Interrupt

# %%
ppms.field_rate
# Out:
# 15

# %%
ppms.field(0.000)

# %%
lockin1.sensitivity()
# Out:
# 0.0005

# %%
lockin2.amplitude()
# Out:
# 0.5

# %%
ppms.field()
# Out:
# 0.024157971143722534

# %%
ppms.temperature()
# Out:
# 1.799999475479126

# %%
ppms.temperature(5)

# %%
lockin1.sensitivity(0.001)
lockin2.sensitivity(0.001)

# %%
gvals = np.linspace(-8, 8, 641)
srdc.volt(-8)
time.sleep(12)
data29, plot29 = npd.single_param_sweep(srdc.volt, gvals, 1.1, lockin1.X, lockin1.Y, lockin2.X, lockin2.Y, DataName='W3_lockin2_12-13_lockin1_11-12_5K_5nA')
# Out:
# Started at 2020-01-09 16:56:50
# DataSet:
#    location = 'data/2020-01-09/#021_W3_lockin2_12-13_lockin1_11-12_5K_5nA_16-56-48'
#    <Type>   | <array_id>    | <array.name> | <array.shape>
#    Setpoint | srdc_volt_set | volt         | (641,)
#    Measured | lockin1_X     | X            | (641,)
#    Measured | lockin1_Y     | Y            | (641,)
#    Measured | lockin2_X     | X            | (641,)
#    Measured | lockin2_Y     | Y            | (641,)
# Finished at 2020-01-09 17:10:07

# %%
srdc.volt(0)

# %%
ppms.temperature_set_stable(10)
gvals = np.linspace(-8, 8, 641)
srdc.volt(-8)
time.sleep(12)
data30, plot30 = npd.single_param_sweep(srdc.volt, gvals, 1.1, lockin1.X, lockin1.Y, lockin2.X, lockin2.Y, DataName='W3_lockin2_12-13_lockin1_11-12_10K_5nA')
# Out:
# Started at 2020-01-09 17:13:14
# DataSet:
#    location = 'data/2020-01-09/#022_W3_lockin2_12-13_lockin1_11-12_10K_5nA_17-13-12'
#    <Type>   | <array_id>    | <array.name> | <array.shape>
#    Setpoint | srdc_volt_set | volt         | (641,)
#    Measured | lockin1_X     | X            | (641,)
#    Measured | lockin1_Y     | Y            | (641,)
#    Measured | lockin2_X     | X            | (641,)
#    Measured | lockin2_Y     | Y            | (641,)
# Finished at 2020-01-09 17:26:30

# %%
plt.figure(figsize=(10, 6))
plt.semilogy(data29.srdc_volt_set[:], np.abs(data29.lockin1_X[:])/5e-9, label= '5K')
plt.semilogy(data30.srdc_volt_set[:], np.abs(data30.lockin1_X[:])/5e-9, label= '10K')
plt.semilogy(data23.srdc_volt_set[:], np.abs(data23.lockin2_X[:])/5e-9, label= '1p8K')
plt.legend()

# %%
plt.figure(figsize=(10, 6))
plt.semilogy(data29.srdc_volt_set[:], np.abs(data29.lockin2_X[:])/5e-9, label= '5K')
plt.semilogy(data30.srdc_volt_set[:], np.abs(data30.lockin2_X[:])/5e-9, label= '10K')
plt.semilogy(data22.srdc_volt_set[:], np.abs(data22.lockin2_X[:])/5e-9, label= '1.8K')
plt.legend()

# %%
lockin1.sensitivity(0.002)
ppms.temperature_set_stable(2)

# %%
16.5/660
# Out:
# 0.025

# %%
gvals = np.linspace(-8.25, 8.25, 661)
Tvals = np.linspace(2, 20, 19)
data31, plot31 = npd.twod_param_sweep(ppms.temperature_set_stable, Tvals, srdc.volt, gvals, lockin1.X, lockin1.Y, lockin2.X, lockin2.Y, SetDelay1=10, SetDelay2=1.1, Param2_SetBetween=0, DataName='W3_lockin2_12-13_lockin1_11-12_Temp2to20K_5nA')
srdc.volt(0)
# Out:
# Started at 2020-01-09 17:59:21
# Temperature timeout
# DataSet:
#    location = 'data/2020-01-09/#023_W3_lockin2_12-13_lockin1_11-12_Temp2to20K_5nA_17-59-18'
#    <Type>   | <array_id>                      | <array.name>           | <array.shape>
#    Setpoint | ppms_temperature_set_stable_set | temperature_set_stable | (19,)
#    Setpoint | srdc_volt_set                   | volt                   | (19, 661)
#    Measured | lockin1_X                       | X                      | (19, 661)
#    Measured | lockin1_Y                       | Y                      | (19, 661)
#    Measured | lockin2_X                       | X                      | (19, 661)
#    Measured | lockin2_Y                       | Y                      | (19, 661)
# Finished at 2020-01-09 22:45:09

# %%
gvals = np.linspace(-8.25, 8.25, 661)
Tvals = np.linspace(22, 118, 49)
data32, plot32 = npd.twod_param_sweep(ppms.temperature_set_stable, Tvals, srdc.volt, gvals, lockin1.X, lockin1.Y, lockin2.X, lockin2.Y, SetDelay1=10, SetDelay2=1.1, Param2_SetBetween=0, DataName='W3_lockin2_12-13_lockin1_11-12_Temp22to118_5nA')
srdc.volt(0)
# Out:
# Started at 2020-01-09 22:45:12
# DataSet:
#    location = 'data/2020-01-09/#024_W3_lockin2_12-13_lockin1_11-12_Temp22to118_5nA_22-45-09'
#    <Type>   | <array_id>                      | <array.name>           | <array.shape>
#    Setpoint | ppms_temperature_set_stable_set | temperature_set_stable | (49,)
#    Setpoint | srdc_volt_set                   | volt                   | (49, 661)
#    Measured | lockin1_X                       | X                      | (49, 661)
#    Measured | lockin1_Y                       | Y                      | (49, 661)
#    Measured | lockin2_X                       | X                      | (49, 661)
#    Measured | lockin2_Y                       | Y                      | (49, 661)
# Finished at 2020-01-10 11:03:44

# %%
gvals = np.linspace(-8.25, 8.25, 661)
Tvals = np.linspace(120, 240, 25)
data33, plot33 = npd.twod_param_sweep(ppms.temperature_set_stable, Tvals, srdc.volt, gvals, lockin1.X, lockin1.Y, lockin2.X, lockin2.Y, SetDelay1=10, SetDelay2=1.1, Param2_SetBetween=0, DataName='W3_lockin2_12-13_lockin1_11-12_Temp120to240_5nA', ZParam=[lockin1.X, lockin2.X])
srdc.volt(0)
# Out:
# Started at 2020-01-10 11:03:46
# DataSet:
#    location = 'data/2020-01-10/#001_W3_lockin2_12-13_lockin1_11-12_Temp120to240_5nA_11-03-45'
#    <Type>   | <array_id>                      | <array.name>           | <array.shape>
#    Setpoint | ppms_temperature_set_stable_set | temperature_set_stable | (25,)
#    Setpoint | srdc_volt_set                   | volt                   | (25, 661)
#    Measured | lockin1_X                       | X                      | (25, 661)
#    Measured | lockin1_Y                       | Y                      | (25, 661)
#    Measured | lockin2_X                       | X                      | (25, 661)
#    Measured | lockin2_Y                       | Y                      | (25, 661)
# Finished at 2020-01-10 17:33:05

# %%
gvals = np.linspace(-8.25, 8.25, 661)
Tvals = np.linspace(250, 300, 6)
data34, plot34 = npd.twod_param_sweep(ppms.temperature_set_stable, Tvals, srdc.volt, gvals, lockin1.X, lockin1.Y, lockin2.X, lockin2.Y, SetDelay1=10, SetDelay2=1.1, Param2_SetBetween=0, DataName='W3_lockin2_12-13_lockin1_11-12_Temp250to300_5nA', ZParam=[lockin1.X, lockin2.X])
srdc.volt(0)
# Out:
# Started at 2020-01-10 17:33:07
# DataSet:
#    location = 'data/2020-01-10/#002_W3_lockin2_12-13_lockin1_11-12_Temp250to300_5nA_17-33-05'
#    <Type>   | <array_id>                      | <array.name>           | <array.shape>
#    Setpoint | ppms_temperature_set_stable_set | temperature_set_stable | (6,)
#    Setpoint | srdc_volt_set                   | volt                   | (6, 661)
#    Measured | lockin1_X                       | X                      | (6, 661)
#    Measured | lockin1_Y                       | Y                      | (6, 661)
#    Measured | lockin2_X                       | X                      | (6, 661)
#    Measured | lockin2_Y                       | Y                      | (6, 661)
# Finished at 2020-01-10 17:34:33
# Keyboard Interrupt

# %%
srdc.volt(0)

# %%
srdc.volt()
# Out:
# 0.0

# %%
lockin2.amplitude(0.004)

# %%
lockin2.amplitude()
# Out:
# 0.004

# %% [markdown]
# now go to M6

# %%
srdc.volt(0)

# %%
lockin2.amplitude(1)

# %%
srdc.volt(7)
time.sleep(7)
gvals = np.linspace(7, -7, 141)
data35, plot35 = npd.single_param_sweep(srdc.volt, gvals, 1, lockin1.X, lockin1.Y, lockin2.X, lockin2.Y, DataName='W6_lockin2_5-6_lockin1_8-9gsweep_RT_10nA')
# Out:
# Started at 2020-01-10 19:41:04
# DataSet:
#    location = 'data/2020-01-10/#003_W6_lockin2_5-6_lockin1_8-9gsweep_RT_10nA_19-41-02'
#    <Type>   | <array_id>    | <array.name> | <array.shape>
#    Setpoint | srdc_volt_set | volt         | (141,)
#    Measured | lockin1_X     | X            | (141,)
#    Measured | lockin1_Y     | Y            | (141,)
#    Measured | lockin2_X     | X            | (141,)
#    Measured | lockin2_Y     | Y            | (141,)
# Finished at 2020-01-10 19:44:00

# %%
srdc.volt(0)

# %%
ppms.temperature_rate = 5
ppms.temperature(2)

# %%
srdc.volt(7)
time.sleep(7)
gvals = np.linspace(7, -7, 141)
data36, plot36 = npd.single_param_sweep(srdc.volt, gvals, 1, lockin1.X, lockin1.Y, lockin2.X, lockin2.Y, DataName='W6_lockin2_5-6_lockin1_8-9gsweep_2_10nA')
# Out:
# Started at 2020-01-10 21:00:14
# DataSet:
#    location = 'data/2020-01-10/#004_W6_lockin2_5-6_lockin1_8-9gsweep_2_10nA_21-00-11'
#    <Type>   | <array_id>    | <array.name> | <array.shape>
#    Setpoint | srdc_volt_set | volt         | (141,)
#    Measured | lockin1_X     | X            | (141,)
#    Measured | lockin1_Y     | Y            | (141,)
#    Measured | lockin2_X     | X            | (141,)
#    Measured | lockin2_Y     | Y            | (141,)
# Finished at 2020-01-10 21:03:09

# %%
srdc.volt(10)
time.sleep(7)
gvals = np.linspace(10, -10, 201)
data37, plot37 = npd.single_param_sweep(srdc.volt, gvals, 1, lockin1.X, lockin1.Y, lockin2.X, lockin2.Y, DataName='W6_lockin2_5-6_lockin1_8-9gsweep_2K_10nA')
# Out:
# Started at 2020-01-10 21:04:45
# DataSet:
#    location = 'data/2020-01-10/#005_W6_lockin2_5-6_lockin1_8-9gsweep_2K_10nA_21-04-42'
#    <Type>   | <array_id>    | <array.name> | <array.shape>
#    Setpoint | srdc_volt_set | volt         | (201,)
#    Measured | lockin1_X     | X            | (201,)
#    Measured | lockin1_Y     | Y            | (201,)
#    Measured | lockin2_X     | X            | (201,)
#    Measured | lockin2_Y     | Y            | (201,)
# Finished at 2020-01-10 21:08:55

# %%
srdc.volt(13)
time.sleep(7)
gvals = np.linspace(13, -13, 261)
data38, plot38 = npd.single_param_sweep(srdc.volt, gvals, 1, lockin1.X, lockin1.Y, lockin2.X, lockin2.Y, DataName='W6_lockin2_5-6_lockin1_8-9gsweep_2K_10nA')
# Out:
# Started at 2020-01-10 21:20:17
# DataSet:
#    location = 'data/2020-01-10/#006_W6_lockin2_5-6_lockin1_8-9gsweep_2K_10nA_21-20-14'
#    <Type>   | <array_id>    | <array.name> | <array.shape>
#    Setpoint | srdc_volt_set | volt         | (261,)
#    Measured | lockin1_X     | X            | (261,)
#    Measured | lockin1_Y     | Y            | (261,)
#    Measured | lockin2_X     | X            | (261,)
#    Measured | lockin2_Y     | Y            | (261,)
# Finished at 2020-01-10 21:25:40

# %%
srdc.volt(-17)

# %%
srdc.volt(-17)
time.sleep(7)
gvals = np.linspace(-17, 17, 341)
data39, plot39 = npd.single_param_sweep(srdc.volt, gvals, 1, lockin1.X, lockin1.Y, lockin2.X, lockin2.Y, DataName='W6_lockin2_5-6_lockin1_8-9gsweep_2K_10nA')
# Out:
# Started at 2020-01-10 21:28:10
# DataSet:
#    location = 'data/2020-01-10/#007_W6_lockin2_5-6_lockin1_8-9gsweep_2K_10nA_21-28-08'
#    <Type>   | <array_id>    | <array.name> | <array.shape>
#    Setpoint | srdc_volt_set | volt         | (341,)
#    Measured | lockin1_X     | X            | (341,)
#    Measured | lockin1_Y     | Y            | (341,)
#    Measured | lockin2_X     | X            | (341,)
#    Measured | lockin2_Y     | Y            | (341,)
# Finished at 2020-01-10 21:35:13

# %%
srdc.volt(0)

# %%
srdc.volt(-17)
time.sleep(7)
gvals = np.linspace(-17, 17, 341)
data40, plot40 = npd.single_param_sweep(srdc.volt, gvals, 1, lockin2.X, lockin2.Y, DataName='W6_lockin2_6-7_gsweep_2K_10nA')
# Out:
# Started at 2020-01-10 21:40:00
# DataSet:
#    location = 'data/2020-01-10/#008_W6_lockin2_6-7_gsweep_2K_10nA_21-39-59'
#    <Type>   | <array_id>    | <array.name> | <array.shape>
#    Setpoint | srdc_volt_set | volt         | (341,)
#    Measured | lockin2_X     | X            | (341,)
#    Measured | lockin2_Y     | Y            | (341,)
# Finished at 2020-01-10 21:46:40

# %%
srdc.volt(-17)
time.sleep(7)
gvals = np.linspace(-17, 17, 341)
data41, plot41 = npd.single_param_sweep(srdc.volt, gvals, 1, lockin2.X, lockin2.Y, DataName='W6_lockin2_13-12_gsweep_2K_10nA')
# Out:
# Started at 2020-01-10 21:51:16
# DataSet:
#    location = 'data/2020-01-10/#009_W6_lockin2_13-12_gsweep_2K_10nA_21-51-15'
#    <Type>   | <array_id>    | <array.name> | <array.shape>
#    Setpoint | srdc_volt_set | volt         | (341,)
#    Measured | lockin2_X     | X            | (341,)
#    Measured | lockin2_Y     | Y            | (341,)
# Finished at 2020-01-10 21:57:55

# %%
srdc.volt(-17)
time.sleep(7)
gvals = np.linspace(-17, 17, 341)
data42, plot42 = npd.single_param_sweep(srdc.volt, gvals, 1, lockin2.X, lockin2.Y, DataName='W6_lockin2_8-9_gsweep_2K_10nA')
# Out:
# Started at 2020-01-10 22:00:38
# DataSet:
#    location = 'data/2020-01-10/#010_W6_lockin2_8-9_gsweep_2K_10nA_22-00-37'
#    <Type>   | <array_id>    | <array.name> | <array.shape>
#    Setpoint | srdc_volt_set | volt         | (341,)
#    Measured | lockin2_X     | X            | (341,)
#    Measured | lockin2_Y     | Y            | (341,)
# Finished at 2020-01-10 22:07:17

# %%
srdc.volt(-17)
time.sleep(7)
gvals = np.linspace(-17, 17, 341)
data43, plot43 = npd.single_param_sweep(srdc.volt, gvals, 1, lockin1.X, lockin1.Y, lockin2.X, lockin2.Y, DataName='W6_lockin2_5-6_lockin1_6-7_gsweep_2K_10nA')
# Out:
# Started at 2020-01-10 22:13:36
# DataSet:
#    location = 'data/2020-01-10/#012_W6_lockin2_5-6_lockin1_6-7_gsweep_2K_10nA_22-13-34'
#    <Type>   | <array_id>    | <array.name> | <array.shape>
#    Setpoint | srdc_volt_set | volt         | (341,)
#    Measured | lockin1_X     | X            | (341,)
#    Measured | lockin1_Y     | Y            | (341,)
#    Measured | lockin2_X     | X            | (341,)
#    Measured | lockin2_Y     | Y            | (341,)
# Finished at 2020-01-10 22:17:39
# Keyboard Interrupt

# %%
gvals = np.linspace(-14, 14, 281)
fieldvals = np.linspace(0, 9000, 181)
data44, plot44 = npd.twod_param_sweep(ppms.field_set_stable, fieldvals, srdc.volt, gvals, lockin1.X, lockin1.Y, lockin2.X, lockin2.Y, SetDelay1=10, SetDelay2=0.7, Param2_SetBetween=-8, DataName='W6_lockin2_5-6_lockin1_6-7_gsweep_2K_Fan0Tto9T_10nA')
srdc.volt(0)
# Out:
# Started at 2020-01-10 22:21:42
# DataSet:
#    location = 'data/2020-01-10/#013_W6_lockin2_5-6_lockin1_6-7_gsweep_2K_Fan0Tto9T_10nA_22-21-38'
#    <Type>   | <array_id>                | <array.name>     | <array.shape>
#    Setpoint | ppms_field_set_stable_set | field_set_stable | (181,)
#    Setpoint | srdc_volt_set             | volt             | (181, 281)
#    Measured | lockin1_X                 | X                | (181, 281)
#    Measured | lockin1_Y                 | Y                | (181, 281)
#    Measured | lockin2_X                 | X                | (181, 281)
#    Measured | lockin2_Y                 | Y                | (181, 281)
# Finished at 2020-01-11 00:07:56
# Keyboard Interrupt

# %%
srdc.volt(0)

# %%
gvals = np.linspace(-10, 10, 201)
fieldvals = np.linspace(0, 9000, 181)
data45, plot45 = npd.twod_param_sweep(ppms.field_set_stable, fieldvals, srdc.volt, gvals, lockin1.X, lockin1.Y, lockin2.X, lockin2.Y, SetDelay1=10, SetDelay2=0.7, Param2_SetBetween=-8, DataName='W6_lockin2_5-6_lockin1_6-7_gsweep_2K_Fan0Tto9T_10nA')
srdc.volt(0)
# Out:
# Started at 2020-01-11 00:10:20
# DataSet:
#    location = 'data/2020-01-11/#001_W6_lockin2_5-6_lockin1_6-7_gsweep_2K_Fan0Tto9T_10nA_00-10-16'
#    <Type>   | <array_id>                | <array.name>     | <array.shape>
#    Setpoint | ppms_field_set_stable_set | field_set_stable | (181,)
#    Setpoint | srdc_volt_set             | volt             | (181, 201)
#    Measured | lockin1_X                 | X                | (181, 201)
#    Measured | lockin1_Y                 | Y                | (181, 201)
#    Measured | lockin2_X                 | X                | (181, 201)
#    Measured | lockin2_Y                 | Y                | (181, 201)
# Finished at 2020-01-11 09:19:14
# Keyboard Interrupt

# %%
lockin2.amplitude(0.004)

# %%
#now W5

# %%
srdc.volt(0)

# %%
srdc.volt(7)
time.sleep(7)
gvals = np.linspace(7, -7, 141)
data46, plot46 = npd.single_param_sweep(srdc.volt, gvals, 1, lockin1.X, lockin1.Y, lockin2.X, lockin2.Y, DataName='W5_lockin2_10-11_lockin1_4-5_gsweep_2_10nA')
# Out:
# Started at 2020-01-11 11:45:57
# DataSet:
#    location = 'data/2020-01-11/#002_W5_lockin2_10-11_lockin1_4-5_gsweep_2_10nA_11-45-55'
#    <Type>   | <array_id>    | <array.name> | <array.shape>
#    Setpoint | srdc_volt_set | volt         | (141,)
#    Measured | lockin1_X     | X            | (141,)
#    Measured | lockin1_Y     | Y            | (141,)
#    Measured | lockin2_X     | X            | (141,)
#    Measured | lockin2_Y     | Y            | (141,)
# Finished at 2020-01-11 11:48:52

# %%
ppms.temperature_rate = 5
ppms.temperature(2)

# %%
srdc.volt(7)
time.sleep(7)
gvals = np.linspace(7, -7, 141)
data47, plot47 = npd.single_param_sweep(srdc.volt, gvals, 1, lockin1.X, lockin1.Y, lockin2.X, lockin2.Y, DataName='W5_lockin2_10-11_lockin1_4-5_gsweep_200K_10nA')
# Out:
# Started at 2020-01-11 12:01:37
# DataSet:
#    location = 'data/2020-01-11/#003_W5_lockin2_10-11_lockin1_4-5_gsweep_200K_10nA_12-01-35'
#    <Type>   | <array_id>    | <array.name> | <array.shape>
#    Setpoint | srdc_volt_set | volt         | (141,)
#    Measured | lockin1_X     | X            | (141,)
#    Measured | lockin1_Y     | Y            | (141,)
#    Measured | lockin2_X     | X            | (141,)
#    Measured | lockin2_Y     | Y            | (141,)
# Finished at 2020-01-11 12:04:32

# %%
srdc.volt(10)
time.sleep(7)
gvals = np.linspace(10, -10, 201)
data48, plot48 = npd.single_param_sweep(srdc.volt, gvals, 1, lockin1.X, lockin1.Y, lockin2.X, lockin2.Y, DataName='W5_lockin2_10-11_lockin1_4-5_gsweep_150K_10nA')
srdc.volt(0)
# Out:
# Started at 2020-01-11 12:11:04
# DataSet:
#    location = 'data/2020-01-11/#004_W5_lockin2_10-11_lockin1_4-5_gsweep_150K_10nA_12-11-01'
#    <Type>   | <array_id>    | <array.name> | <array.shape>
#    Setpoint | srdc_volt_set | volt         | (201,)
#    Measured | lockin1_X     | X            | (201,)
#    Measured | lockin1_Y     | Y            | (201,)
#    Measured | lockin2_X     | X            | (201,)
#    Measured | lockin2_Y     | Y            | (201,)
# Finished at 2020-01-11 12:15:14

# %%
srdc.volt(13)
time.sleep(7)
gvals = np.linspace(13, -13, 261)
data49, plot49 = npd.single_param_sweep(srdc.volt, gvals, 1, lockin1.X, lockin1.Y, lockin2.X, lockin2.Y, DataName='W5_lockin2_10-11_lockin1_4-5_gsweep_2K_10nA')
srdc.volt(0)
# Out:
# Started at 2020-01-11 14:25:43
# DataSet:
#    location = 'data/2020-01-11/#007_W5_lockin2_10-11_lockin1_4-5_gsweep_2K_10nA_14-25-41'
#    <Type>   | <array_id>    | <array.name> | <array.shape>
#    Setpoint | srdc_volt_set | volt         | (261,)
#    Measured | lockin1_X     | X            | (261,)
#    Measured | lockin1_Y     | Y            | (261,)
#    Measured | lockin2_X     | X            | (261,)
#    Measured | lockin2_Y     | Y            | (261,)
# Finished at 2020-01-11 14:31:07

# %%
srdc.volt(13)#14-3
time.sleep(7)
gvals = np.linspace(13, -13, 261)
data50, plot50 = npd.single_param_sweep(srdc.volt, gvals, 1, lockin2.X, lockin2.Y, DataName='W5_lockin2_14-13_gsweep_2K_10nA')
srdc.volt(0)
# Out:
# Started at 2020-01-11 14:59:41
# DataSet:
#    location = 'data/2020-01-11/#008_W5_lockin2_14-13_gsweep_2K_10nA_14-59-40'
#    <Type>   | <array_id>    | <array.name> | <array.shape>
#    Setpoint | srdc_volt_set | volt         | (261,)
#    Measured | lockin2_X     | X            | (261,)
#    Measured | lockin2_Y     | Y            | (261,)
# Finished at 2020-01-11 15:04:46

# %%
srdc.volt(13)
time.sleep(7)
gvals = np.linspace(13, -13, 261)
data51, plot51 = npd.single_param_sweep(srdc.volt, gvals, 1, lockin2.X, lockin2.Y, DataName='W5_lockin2_3-4_gsweep_2K_10nA')
srdc.volt(0)
# Out:
# Started at 2020-01-11 15:07:38
# DataSet:
#    location = 'data/2020-01-11/#009_W5_lockin2_3-4_gsweep_2K_10nA_15-07-37'
#    <Type>   | <array_id>    | <array.name> | <array.shape>
#    Setpoint | srdc_volt_set | volt         | (261,)
#    Measured | lockin2_X     | X            | (261,)
#    Measured | lockin2_Y     | Y            | (261,)
# Finished at 2020-01-11 15:12:44

# %%
srdc.volt(13)
time.sleep(7)
gvals = np.linspace(13, -13, 261)
data52, plot52 = npd.single_param_sweep(srdc.volt, gvals, 1, lockin2.X, lockin2.Y, DataName='W5_lockin2_4-5_gsweep_2K_10nA')
srdc.volt(0)
# Out:
# Started at 2020-01-11 15:14:37
# DataSet:
#    location = 'data/2020-01-11/#010_W5_lockin2_4-5_gsweep_2K_10nA_15-14-36'
#    <Type>   | <array_id>    | <array.name> | <array.shape>
#    Setpoint | srdc_volt_set | volt         | (261,)
#    Measured | lockin2_X     | X            | (261,)
#    Measured | lockin2_Y     | Y            | (261,)
# Finished at 2020-01-11 15:19:43

# %%
srdc.volt(13)
time.sleep(7)
gvals = np.linspace(13, -13, 261)
data53, plot53 = npd.single_param_sweep(srdc.volt, gvals, 1, lockin1.X, lockin1.Y, lockin2.X, lockin2.Y, DataName='W5_lockin1_14-3_lockin2_4-5_gsweep_2K_10nA')
srdc.volt(0)
# Out:
# Started at 2020-01-11 15:25:46
# DataSet:
#    location = 'data/2020-01-11/#011_W5_lockin1_14-3_lockin2_4-5_gsweep_2K_10nA_15-25-44'
#    <Type>   | <array_id>    | <array.name> | <array.shape>
#    Setpoint | srdc_volt_set | volt         | (261,)
#    Measured | lockin1_X     | X            | (261,)
#    Measured | lockin1_Y     | Y            | (261,)
#    Measured | lockin2_X     | X            | (261,)
#    Measured | lockin2_Y     | Y            | (261,)
# Finished at 2020-01-11 15:31:11

# %%
gvals = np.linspace(-10, 10, 501)
fieldvals = np.linspace(0, 9000, 181)
data54, plot54 = npd.twod_param_sweep(ppms.field_set_stable, fieldvals, srdc.volt, gvals, lockin1.X, lockin1.Y, lockin2.X, lockin2.Y, SetDelay1=10, SetDelay2=0.7, Param2_SetBetween=-8, DataName='W5_lockin1_14-3_lockin2_4-5_gsweep_1.8K_Fan0Tto9T_10nA')
srdc.volt(0)
# Out:
# Started at 2020-01-11 15:33:12
# DataSet:
#    location = 'data/2020-01-11/#012_W5_lockin1_14-3_lockin2_4-5_gsweep_1.8K_Fan0Tto9T_10nA_15-33-09'
#    <Type>   | <array_id>                | <array.name>     | <array.shape>
#    Setpoint | ppms_field_set_stable_set | field_set_stable | (181,)
#    Setpoint | srdc_volt_set             | volt             | (181, 501)
#    Measured | lockin1_X                 | X                | (181, 501)
#    Measured | lockin1_Y                 | Y                | (181, 501)
#    Measured | lockin2_X                 | X                | (181, 501)
#    Measured | lockin2_Y                 | Y                | (181, 501)
# Finished at 2020-01-12 13:41:47

# %%
ppms.field(0)

# %%
plot54[0]

# %%
plot54[2]

# %%
srdc.volt(-8)
time.sleep(7)
gvals = np.linspace(-8, 8, 321)
data55, plot55 = npd.single_param_sweep(srdc.volt, gvals, 1, lockin1.X, lockin1.Y, lockin2.X, lockin2.Y, DataName='W5_lockin1_14-3_lockin2_4-5_gsweep_1.8K_10nA')
srdc.volt(0)
# Out:
# Started at 2020-01-12 15:00:10
# DataSet:
#    location = 'data/2020-01-12/#002_W5_lockin1_14-3_lockin2_4-5_gsweep_1.8K_10nA_15-00-08'
#    <Type>   | <array_id>    | <array.name> | <array.shape>
#    Setpoint | srdc_volt_set | volt         | (321,)
#    Measured | lockin1_X     | X            | (321,)
#    Measured | lockin1_Y     | Y            | (321,)
#    Measured | lockin2_X     | X            | (321,)
#    Measured | lockin2_Y     | Y            | (321,)
# Finished at 2020-01-12 15:06:17

# %%
lockin2.amplitude(1.5)

# %%
gvals = np.linspace(-8, 8, 641)
Tvals = np.linspace(2, 20, 19)
data56, plot56 = npd.twod_param_sweep(ppms.temperature_set_stable, Tvals, srdc.volt, gvals, lockin1.X, lockin1.Y, lockin2.X, lockin2.Y, SetDelay1=10, SetDelay2=1.1, Param2_SetBetween=0, DataName='W5_lockin1_14-3_lockin2_4-5_Temp2to20K_15nA')
srdc.volt(0)
# Out:
# Started at 2020-01-12 15:09:45

# %%
gvals = np.linspace(-8, 8, 641)
Tvals = np.linspace(22, 118, 49)
data57, plot57 = npd.twod_param_sweep(ppms.temperature_set_stable, Tvals, srdc.volt, gvals, lockin1.X, lockin1.Y, lockin2.X, lockin2.Y, SetDelay1=10, SetDelay2=1.1, Param2_SetBetween=0, DataName='W5_lockin1_14-3_lockin2_4-5_Temp22to118_15nA')
srdc.volt(0)
